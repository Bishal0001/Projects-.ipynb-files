# %% [markdown]
# # About Yulu
#
# - Yulu is India’s leading micro-mobility service provider, which offers unique vehicles for the daily commute. Starting off as a mission to eliminate traffic congestion in India, Yulu provides the safest commute solution through a user-friendly mobile app to enable shared, solo and sustainable commuting.
#
#
#
#
# - Yulu zones are located at all the appropriate locations (including metro stations, bus stands, office spaces, residential areas, corporate offices, etc) to make those first and last miles smooth, affordable, and convenient!

# %% [markdown]
# # Business Problem
#
# Yulu has recently suffered considerable dips in its revenues. They have contracted a consulting company to understand the factors on which the demand for these shared electric cycles depends. Specifically, they want to understand the factors affecting the demand for these shared electric cycles in the Indian market.

# %% [markdown]
# # Yulu : Hypothesis Testing

# %% [markdown]
# ## Recommendations.
#
# - On rainy weather Yulu has least cycle renting counts, hence Yulu should focus more incase of increasing counts on rainy weathers.
#
#
#
# - A cyclical trend can be noticed between 2011 and 2012 data, based on which it seems all jan, feb, march possess least cycle renting counts and the factors behind this is windspeed above 22, high humidity.
#
#
#
# - High variance of humidity can cause low user count, as it can be seen that 2012 have lower variance than 2011 with high user count.
#
#
#
# -  By taking above weather factors Yulu's user counts can be roughly predicted and Yulu should focus in it.
#
#
#
#
# -  As january fridays and february mondays have least probability of 6 % each of renting electric cycles, Yulu should focus on this.
#
#
#
# -  Yulu should focus on increasing user counts on mist cloudy, light rainy snowy, heavy rainy weather,as  these weathers has only 35 % probability of renting electric cycles.

# %% [markdown]
# ## Insights.
#
# -  From advanced statistical tests it can be concluded that renting electric cycles in working day is not equal to non-working day.
#
#
#
# -  From advanced statistical tests it can be concluded that no of cycles renting is not similar in different weathers.
#
#
#
# -  From advanced statistical tests it can be concluded that no of cycles renting is not similar in different seasons.
#
#
#
# -  From advanced statistical tests it can be concluded that weathers and seasons are dependent.
#
#
#
# - Registerd users are almost double than casual users.
#
#
# -  Least elctric cycle renting can be seen on heavy rainy weather.
#
#
# -  Maximum electric cycle renting can be seen on clear cloudy weather.
#
#
#
# -  On clear cloudy weather all four seasons have above 60 % of probability of renting electric cycles.
#
#
#
# -  On heavy rainy weather all four seasons have  0 % of probability of renting electric cycles.
#
#
#
# -   On mist cloudy weather all four seasons have between 20 - 30 % of probability of renting electric cycles.
#
#
#
# -  On light snowy rainy weather all four seasons have nearly 10 % of probability of renting electric cycles.
#
#
#
# - Trends are cyclical in nature as we can observe both the least active months are at the starting and specifically January.
#
#
#
# - In both the year  peak of active users were between June - July.
#
#
#
# - Drastic increase of users in the begining of the year uptill June and July.
#
#
#
# - Most suitable weather for yulu bike rent business is clear cloud weather, as it attracts most of their user ie on an average 205 users.
#
#
# - Yulu should focus on their business at heavy rainy weather, as it has the least user count with 1 user.
#
#
# - Top 95% users for weather 1 lies between 202 - 207 approx.
#
#
# - Top 95% users for weather 2 lies between 175 - 182 approx.
#
#
# - Top 95% users for weather 3 lies between 114 - 123 approx.
#
#
#
# - Casual users decreases at workingdays.
#
#
# - Casual users decreases as humidity increases.
#
#
# - Casual users increases as atemp increases.
#
#
# - Casual users increases as temp increases.
#
#
# - Registered users decreases as humidity increases.
#
#
# - Count of users slightly decreases as weather increases.
#
#
# - Count of users increases as atemp increases.
#
#
# - Count of users increases as temp increases.
#
#
# - Registered users increases as casual users increases.
#
#
#
# -  From may to october Yulu sees a stable rate of electric cycle renting.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Important Notes
#
# - ``season :``
#
# ```
#
# 1: spring
#
# 2: summer
#
# 3: fall
#
# 4: winter
#
# ```
#
#
#
# -  ```weather:```
#
# ```
#
# 1: Clear, Few clouds, partly cloudy, partly cloudy
#
# 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#
# 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#
# 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
#
# ```

# %% [markdown]
# # Project starts here.

# %% [markdown]
# ### All the codes, plots, statistical tests, observations are done below.

# %%
import pandas as pd
import numpy as np 
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns
from numpy.random import seed
from numpy.random import randint
from numpy import mean
from sklearn.utils import resample
from sklearn.metrics import accuracy_score
import warnings
import datetime as dt 
from sorted_months_weekdays import *
from sort_dataframeby_monthorweek import *
warnings.filterwarnings("ignore")
import statsmodels.api as sm
from bioinfokit.analys import stat

# %%
yulu = pd.read_csv('Yulu.csv')
df = pd.read_csv('Yulu.csv')
df.head()

# %%
yulu.shape
# Out:
# (10886, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
#  12  year        10886 non-null  object
#  13  date        10886 non-null  object
#  14  month       10886 non-null  object
#  15  day         10886 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(8), object(4)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.describe(include='object')
# Out:
#          year   date  month    day
# count   10886  10886  10886  10886
# unique      2     19     12      7
# top      2012     01    May    Sat
# freq     5464    575    912   1584

# %%
#yulu['datetime'] = yulu['datetime'].astype('datetime64[ns]')
yulu['datetime'] = pd.to_datetime(yulu['datetime'])
df['datetime'] = pd.to_datetime(df['datetime'])
df['year'] = df.datetime.dt.strftime('%Y')
df['date'] = df.datetime.dt.strftime('%d')
df['month'] = df.datetime.dt.strftime('%B')
df['day'] = df.datetime.dt.strftime('%a')

yulu.nunique()
#df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year date    month  day
# 0        81        0.0       3          13     16  2011   01  January  Sat
# 1        80        0.0       8          32     40  2011   01  January  Sat
# 2        80        0.0       5          27     32  2011   01  January  Sat
# 3        75        0.0       3          10     13  2011   01  January  Sat
# 4        75        0.0       0           1      1  2011   01  January  Sat

# %% [markdown]
# ## Basic EDA.

# %%
for i in ['year','month','day','season','holiday','workingday','weather']:
    print(df[i].value_counts(normalize=True)*100)
    print('-'*50)
# Out:
# 2012    50.192908
# 2011    49.807092
# Name: year, dtype: float64
# --------------------------------------------------
# May          8.377733
# June         8.377733
# July         8.377733
# August       8.377733
# December     8.377733
# October      8.368547
# November     8.368547
# April        8.350175
# September    8.350175
# February     8.276686
# March        8.276686
# January      8.120522
# Name: month, dtype: float64
# --------------------------------------------------
# Sat    14.550799
# Sun    14.504869
# Thu    14.266030
# Mon    14.247658
# Wed    14.247658
# Tue    14.137424
# Fri    14.045563
# Name: day, dtype: float64
# --------------------------------------------------
# 4    25.114826
# 2    25.105640
# 3    25.105640
# 1    24.673893
# Name: season, dtype: float64
# --------------------------------------------------
# 0    97.14312
# 1     2.85688
# Name: holiday, dtype: float64
# --------------------------------------------------
# 1    68.087452
# ...

# %%
# What weather provides best booking.

weather_df = df.groupby('weather').nunique().reset_index()
weather_df = weather_df[['weather','count','registered','casual']]
#weather_df
# Out:
#    weather  count  registered  casual
# 0        1    789         689     295
# 1        2    593         520     202
# 2        3    310         274     107
# 3        4      1           1       1

# %%
yulu.hist(bins=20,figsize=(20,15),color='lightblue')
plt.show()

# %%
def cond_prob(i,j):
    Joint_vals_fitness = pd.crosstab(i,j,normalize=True)
    product = Joint_vals_fitness.sum(axis=0)
    cond_Prob = Joint_vals_fitness.divide(product,axis=1)
    return cond_Prob.plot.bar(figsize=(15,6),grid=True,color=('r','g','y','grey'))


def cond_prob(i,j):
    Joint_vals_fitness = pd.crosstab(i,j,normalize=True)
    product = Joint_vals_fitness.sum(axis=0)
    cond_Prob = Joint_vals_fitness.divide(product,axis=1)
    Sort_Dataframeby_Month(df=cond_p,monthcolumnname='month')
    return cond_Prob.plot.bar(figsize=(15,6),grid=True,color=('r','g','y','grey','m','c','black'))

cond_p = df[['weather','month','season','count','day']]

conditions = [
(cond_p['season'] == 1),
(cond_p['season'] == 2), 
(cond_p['season'] == 3), 
(cond_p['season'] == 4) ]

values = ['spring','summer','fall','winter']

cond_p['season'] = np.select(conditions,values)
#cond_p


conditions1 = [
(cond_p['weather'] == 1),
(cond_p['weather'] == 2), 
(cond_p['weather'] == 3), 
(cond_p['weather'] == 4) ]

values1 = ['clear cloud','mist cloud','light snowy rainy','heavy rainy']


cond_p['weather'] = np.select(conditions1,values1)
#cond_p
# Out:
#            weather     month  season  count  day
# 0      clear cloud   January  spring     16  Sat
# 1      clear cloud   January  spring     40  Sat
# 2      clear cloud   January  spring     32  Sat
# 3      clear cloud   January  spring     13  Sat
# 4      clear cloud   January  spring      1  Sat
# ...            ...       ...     ...    ...  ...
# 10881  clear cloud  December  winter    336  Wed
# 10882  clear cloud  December  winter    241  Wed
# 10883  clear cloud  December  winter    168  Wed
# 10884  clear cloud  December  winter    129  Wed
# 10885  clear cloud  December  winter     88  Wed
#
# [10886 rows x 5 columns]

# %%
cond_prob(cond_p['month'],cond_p['day'])
plt.title('Monthly probability of electric cycle renting on day-basis',fontsize=20,fontname='Comic Sans MS')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Observation from above plot.
#
#
#
# - Highest probability of renting electric cycles on sundays falls on apr, dec, jan, jul, jun, sep.
#
#
# - Lowest probability of renting electric cycles on sundays falls on aug, feb, mar, may, nov, oct.
#
#
#
#
# -  Highest probability of renting electric cycles on mondays falls on apr, dec, jan, jul, oct, sep.
#
# - Lowest probability of renting electric cycles on mondays falls on feb.
#
#
#
#
# -  Highest probability of renting electric cycles on tuesdays falls on apr, jul, may, oct.
#
# - Lowest probability of renting electric cycles on tuesdays falls on aug, dec, feb, jun, mar, nov, sep.
#
#
#
#
# -  Highest probability of renting electric cycles on wednesdays falls on aug, feb, jan, may, oct.
#
#
# - Lowest probability of renting electric cycles on wednesdays falls on apr, dec, jul, jun, mar, nov, sep.
#
#
#
#
#
# -  Highest probability of renting electric cycles on thursdays falls on aug, feb, mar, nov.
#
# - Lowest probability of renting electric cycles on thursdays falls on apr, dec, jan, jul, jun, oct, sep.
#
#
#
#
# -  Highest probability of renting electric cycles on fridays falls on aug, feb, jun, mar, nov.
#
# - Lowest probability of renting electric cycles on fridays falls on jan.
#
#
#
#
# -  Highest probability of renting electric cycles on satardays falls on dec, feb, jun, mar, nov, sep.
#
# -  Lowest probability of renting electric cycles on satardays falls on apr, aug, jan, jul, may, oct.

# %%
weather_df = df.groupby('weather').nunique().reset_index()
weather_df = weather_df[['weather','count','registered','casual']]
#weather_df

# %%
weather_df.plot.bar(figsize=(15,7),color={'black','m','grey'})
# plt.grid()
# plt.title('Users with respect of weather.',fontsize=20,fontname='Comic Sans MS')
x1 = [0,1,2,3]
values1 = ['clear cloud','mist cloud','light snowy rainy','heavy rainy']
plt.xticks(x1,values1,rotation=45)

plt.show()

# %% [markdown]
# ## Observation from above plot.
#
# - Registerd users are almost double than casual users.
#
#
# -  Least elctric cycle renting can be seen on heavy rainy weather.
#
#
# -  Maximum electric cycle renting can be seen on clear cloudy weather.

# %%
cond_prob(df['weather'],cond_p['season'])
x1 = [0,1,2,3]
values1 = ['clear cloud','mist cloud','light snowy rainy','heavy rainy']
plt.xticks(x1,values1,rotation=45)
plt.title('Probability of electric cycles renting of seasons according to weather ',fontsize=20,fontname='Comic Sans MS')

plt.show()

# %% [markdown]
# ## Observation from above plot.
#
#
# -  On clear cloudy weather all four seasons have above 60 % of probability of renting electric cycles.
#
#
#
# -  On heavy rainy weather all four seasons have  0 % of probability of renting electric cycles.
#
#
#
# -   On mist cloudy weather all four seasons have between 20 - 30 % of probability of renting electric cycles.
#
#
#
# -  On light snowy rainy weather all four seasons have nearly 10 % of probability of renting electric cycles.

# %%
#.
windspeed_df = df.groupby('windspeed').nunique().reset_index()
windspeed_df = windspeed_df[['windspeed','count','humidity','atemp','temp']]
# windspeed_df

# %%
#.
plt.figure(figsize=(15,7))
sns.scatterplot(data=windspeed_df,x='windspeed',y='count',hue='atemp')
plt.title('Correlation between count and windspeed.',fontsize=20,fontname='Comic Sans MS')

plt.show()

# %% [markdown]
# ##  Observations from above scatterplot
#
# - It can be concluded that with the increase of windspeed Yulu's user count drastically fall.
#
#
# - As windspeed increases atemp falls to its lowest.

# %%
month_df = df.groupby('month').nunique().reset_index()
month_df = month_df[['month','count','casual','registered']]
month_df = Sort_Dataframeby_Month(df=month_df,monthcolumnname='month')

# %%
#.
fig = plt.figure(figsize = (15,10))

ax1 = fig.add_subplot(211)
sns.lineplot(x = 'season', y = 'count', data = yulu,color='y')
ax1.set_title('Lineplot for season vs corresponding electric cycle renting counts',fontsize=20,fontname='Comic Sans MS')


plt.show()

# %% [markdown]
# ## Observations from seasons data.
#
# - Users increased renting bikes with the increase of seasons.
#
#
# - Most of their users were seen on fall ie season 3.
#
#
# - Least of their users were seen in spring ie season 1.

# %%
#.
plt.figure(figsize=(15,5))
year1_df = df[df['year'] == '2011']
year1_df
sns.lineplot(x='month',y='count',data=year1_df,color='green')
plt.title('2011 data, Observing cyclical pattern between 2011 and 2012 that is indeed present',fontsize=14,fontname='Comic Sans MS')
plt.xticks(rotation=45)
plt.axvspan(xmin=6,xmax=11,color='y',alpha=.1)
plt.show()


plt.figure(figsize=(15,5))
year2_df = df[df['year'] == '2012']
year2_df
sns.lineplot(x='month',y='count',data=year2_df,color='g')
plt.title('2012 data, Observing cyclical pattern between 2011 and 2012 that is indeed present',fontsize=14,fontname='Comic Sans MS')
plt.xticks(rotation=45)
plt.axvspan(xmin=8,xmax=11,color='y',alpha=.1)

plt.show()

# %% [markdown]
# ## Observations from comparison of 2011 and 2012 data.
#
# - Trends are cyclical in nature as we can observe both the least active months are at the starting and specifically January.
#
#
#
# - In both the year  peak of active users were between June - July.
#
#
#
# - Drastic increase of users in the begining of the year uptill June and July.

# %%
#.
weather_1_means = [yulu[yulu['weather'] == 1]['count'].sample(5753).mean()for i in range(100000)]
ci = np.percentile(weather_1_means,[2.5,97.5])
plt.figure(figsize=(15,7))
x = sns.histplot(weather_1_means,bins=100,kde=True,color = 'lightgreen')
x.lines[0].set_color('r')

plt.axvline(x = ci[0],c = 'black', lw=5)
plt.axvline(x = ci[1],c = 'black', lw=5)
plt.title(f'95% population count lies between {round(ci[0],2)} - {round(ci[1],2)} for Clear, Few clouds, partly cloudy, partly cloudy weather ie weather 1',fontsize=14,fontname='Comic Sans MS')
plt.show()



weather_2_means = [yulu[yulu['weather'] == 2]['count'].sample(2267).mean()for i in range(100000)]
ci2 = np.percentile(weather_2_means,[2.5,97.5])
plt.figure(figsize=(15,7))
x = sns.histplot(weather_2_means,bins=100,kde=True,color = 'lightgreen')
x.lines[0].set_color('r')
plt.axvline(x = ci2[0],c = 'black', lw=5)
plt.axvline(x = ci2[1],c = 'black', lw=5)
plt.title(f'95% population count lies between {round(ci2[0],2)} - {round(ci2[1],2)} for Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist ie weather 2',fontsize=14,fontname='Comic Sans MS')
plt.show()



weather_3_means = [yulu[yulu['weather'] == 3]['count'].sample(687).mean()for i in range(100000)]
ci3 = np.percentile(weather_3_means,[2.5,97.5])
plt.figure(figsize=(15,7))
x=sns.histplot(weather_3_means,bins=100,kde=True,color = 'lightgreen')
x
x.lines[0].set_color('r')
plt.axvline(x = ci3[0],c = 'black', lw=5)
plt.axvline(x = ci3[1],c = 'black', lw=5)
plt.title(f'95% population count lies between {round(ci3[0],2)} - {round(ci3[1],2)} for Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds Mist ie weather 3',fontsize=11,fontname='Comic Sans MS')
plt.show()

# %% [markdown]
# ## Observations from weather data.
#
# - Most suitable weather for yulu bike rent business is clear cloud weather, as it attracts most of their user ie on an average 205 users.
#
#
# - Yulu should focus on their business at heavy rainy weather, as it has the least user count with 1 user.
#
#
# - Top 95% users for weather 1 lies between 202 - 207 approx.
#
#
# - Top 95% users for weather 2 lies between 175 - 182 approx.
#
#
# - Top 95% users for weather 3 lies between 114 - 123 approx.

# %%
#.
corr = yulu.corr()
plt.figure(figsize=(17,6))
sns.heatmap(corr,cmap='Spectral_r')
plt.title('Correlation between all the variables',fontsize=20,fontname='Comic Sans MS')
plt.show()

# %% [markdown]
# ## Observations from multivariate analysis.
#
# - Casual users decreases at workingdays.
#
#
# - Casual users decreases as humidity increases.
#
#
# - Casual users increases as atemp increases.
#
#
# - Casual users increases as temp increases.
#
#
# - Registered users decreases as humidity increases.
#
#
# - Count of users slightly decreases as weather increases.
#
#
# - Count of users increases as atemp increases.
#
#
# - Count of users increases as temp increases.
#
#
# - Registered users increases as casual users increases.

# %% [markdown]
# ## Basic EDA ends.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##  ( *** ) Explored insights to deal with the issue Yulu faced regarding its user count fall.

# %%
df_11 = df[df['year'] == '2011']
df_12 = df[df['year'] == '2012']

# %%
a_11 = df_11.groupby('month')[['windspeed','count','humidity','temp','atemp','weather','datetime']].nunique()
aa_11 = pd.DataFrame(a_11).reset_index().sort_values(by='count',ascending = False)

# %%
a_12 = df_12.groupby('month')[['windspeed','count','humidity','temp','atemp','weather','datetime']].nunique()
aa_12 = pd.DataFrame(a_12).reset_index().sort_values(by='count',ascending = False)

# %%
month_df.plot.bar(x='month',color={'m','grey','black'},figsize=(13,5))
plt.title('Month-wise user counts.',fontsize=20,fontname='Comic Sans MS')

plt.show()

# %% [markdown]
# ## Observation from month-wise data.
#
#
# - As January, February, March sees the least number of user, factors regarding the issue should be catagorised briefly.
#
#
# -  Registerd users nearly double the counts compared to casual users.
#
#
# -  From may to october Yulu sees a stable rate of electric cycle renting.

# %% [markdown]
# ## Yearly user counts.

# %%
plt.figure(figsize=(13,3))
sns.lineplot(data=aa_11,x='month',y='count',color='m')
plt.axvspan(xmin=5,xmax=11,color='y',alpha=.1)
plt.title('2011 User Count ',fontsize=25,fontname='Comic Sans MS')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')
plt.show()

plt.figure(figsize=(13,3))
sns.lineplot(data=aa_12,x='month',y='count',color='m')
plt.axvspan(xmin=8,xmax=11,color='y',alpha=.1)
plt.title('2012 User Count ',fontsize=25,fontname='Comic Sans MS')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')

plt.show()

# %% [markdown]
# # Problem Statements.
#
#
# - Problem Statement1 : Fall of user counts for renting electric cycles.
#
#
# - Problem Statement2 : What factor is responsible for high user count in 2012.
#
#
# - Problem Statement3 : Why 2012 seen less user count fall then 2011.

# %% [markdown]
# ## Factor :  Windspeed

# %%
fig = plt.figure(figsize=(16,8))

ax = fig.add_subplot(221)
sns.lineplot(data=aa_11,x='month',y='count',color='m')
plt.axvspan(xmin=5,xmax=11,color='y',alpha=.1)
plt.title('2011 User Count ',fontsize=25,fontname='Comic Sans MS')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')


ax = fig.add_subplot(222)
sns.lineplot(data=aa_12,x='month',y='count',color='m')
plt.axvspan(xmin=8,xmax=11,color='y',alpha=.1)
plt.title('2012 User Count ',fontsize=25,fontname='Comic Sans MS')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')


ax = fig.add_subplot(223)
sns.lineplot(data=aa_11,x='month',y='windspeed',color='m')
plt.axvspan(xmin=5,xmax=11,color='y',alpha=.1)
plt.title('2011 Windspeed Month-wise ',fontsize=14,fontname='Comic Sans MS')
plt.axhline(20,c='grey')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')



ax = fig.add_subplot(224)
sns.lineplot(data=aa_12,x='month',y='windspeed',color='m')
plt.axvspan(xmin=8,xmax=11,color='y',alpha=.1)
plt.title('2012 Windspeed Month-wise ',fontsize=14,fontname='Comic Sans MS')
plt.axhline(21,c='grey')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')

plt.subplots_adjust( wspace=0.2, hspace=.5)
plt.show()

# %% [markdown]
# ## Observation from  Windspeed
#
#
# - User count drastically fall when windspeed roughly exeeds 20,21 mark.
#
#
# - We can observe, user count decreases with the increase of windspeed.
#
#
# - Mostly January, February, March possess high windspeed and lowest user count.

# %% [markdown]
# ## Factor : Temperature Feel (atemp)

# %%
fig = plt.figure(figsize=(16,8))

ax = fig.add_subplot(221)
sns.lineplot(data=aa_11,x='month',y='count',color='m')
plt.axvspan(xmin=7,xmax=11,color='y',alpha=.1)
plt.title('2011 User Count ',fontsize=25,fontname='Comic Sans MS')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')


ax = fig.add_subplot(222)
sns.lineplot(data=aa_12,x='month',y='count',color='m')
plt.axvspan(xmin=8,xmax=11,color='y',alpha=.1)
plt.title('2012 User Count ',fontsize=25,fontname='Comic Sans MS')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')


ax = fig.add_subplot(223)
sns.lineplot(data=aa_11,x='month',y='atemp',color='m')
plt.axvspan(xmin=7,xmax=11,color='y',alpha=.1)
plt.title('2011 Temperature Feeling ',fontsize=14,fontname='Comic Sans MS')
plt.yticks(c='grey')
plt.xticks(rotation = 45,c='grey')
plt.axhline(27,c='grey')


ax = fig.add_subplot(224)
sns.lineplot(data=aa_12,x='month',y='atemp',color='m')
plt.axvspan(xmin=8,xmax=11,color='y',alpha=.1)
plt.title('2012 Temperature Feeling ',fontsize=14,fontname='Comic Sans MS')
plt.axhline(27,c='grey')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')

plt.subplots_adjust( wspace=0.2, hspace=.5)
plt.show()

# %% [markdown]
# ## Observation from temperature feel (atemp)
#
#
# - User count drastically fall when atemp  exeeds roughly 27 mark.
#
#
# - We can observe, user count decreases with the increase of atemp.
#
#
# - Mostly January, February, March possess high atemp and lowest user count.

# %% [markdown]
# ## Factor : Humidity

# %%
fig = plt.figure(figsize=(16,11))

ax = fig.add_subplot(321)
sns.lineplot(data=aa_11,x='month',y='count',color='m')
plt.axvspan(xmin=5,xmax=11,color='y',alpha=.1)
plt.title('2011 User Count ',fontsize=25,fontname='Comic Sans MS')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')


ax = fig.add_subplot(322)
sns.lineplot(data=aa_12,x='month',y='count',color='m')
plt.axvspan(xmin=6,xmax=11,color='y',alpha=.1)
plt.title('2012 User Count ',fontsize=25,fontname='Comic Sans MS')
plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')


ax = fig.add_subplot(323)
sns.lineplot(data=aa_11,x='month',y='humidity',color='m')
plt.axvspan(xmin=5,xmax=11,color='y',alpha=.1)
plt.title('2011 Humidity Month-wise ',fontsize=14,fontname='Comic Sans MS')
plt.yticks(c='grey')
plt.xticks(rotation = 45,c='grey')


ax = fig.add_subplot(324)
sns.lineplot(data=aa_12,x='month',y='humidity',color='m')
plt.axvspan(xmin=6,xmax=11,color='y',alpha=.1)
plt.title('2012 Humidity Month-wise ',fontsize=14,fontname='Comic Sans MS')

plt.xticks(rotation = 45,c='grey')
plt.yticks(c='grey')

ax = fig.add_subplot(325)
aa_11['humidity'].hist(bins=5,color='lightblue')


ax = fig.add_subplot(326)
aa_12['humidity'].hist(bins=5,color='lightblue')
plt.subplots_adjust( wspace=0.2, hspace=.7)
plt.show()

# %% [markdown]
# ## Observations from humidity.
#
#
# - We can clearly differentiate the variance of the humidity is lower in 2012.
#
#
# - More importantly 2012 didnt showed any extreme variance as 2011 which indeed cause low user fall in 2012.
#
#
# - From both 2011 and 2012 data we can predict a trend that extreme high humidity can be seen in the begining months of the year like jan, feb, mar which in case have least user renting electric cycles.

# %% [markdown]
# # Recommendations based on above weather factor insights.
#
# - From the above observation i can state the worst months for Yulu is Jan, Feb, Mar as all three months gets badly affected by adverse humidity, windspeed, atemp factors.
#
#
# -  As the trend looks cyclical i can predict the year begining will face lowest user counts.
#
#
# - It can be concluded that the lower the humidity variance the higher the user counts

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # -  Hypothesis Testing begins here.

# %% [markdown]
# ## 2 Sample TTest

# %% [markdown]
# ```2- Sample T-Test to check if Working Day has an effect on the number of electric cycles rented (10 points)```

# %%
w0 = df[df['workingday'] == 0][['workingday','count']]
w1 = df[df['workingday'] == 1][['workingday','count']]
w1m = w1['count']
w0m = w0['count']

# %%
log_w0m = np.log10(w0m)
log_w1m = np.log10(w1m)

boxcox_w0m = stats.boxcox(w0m)
boxcox_w0m = boxcox_w0m[0]

boxcox_w1m = stats.boxcox(w1m)
boxcox_w1m = boxcox_w1m[0]

# %%
fig = plt.figure(figsize=(13,7))

ax = fig.add_subplot(221)
sns.boxplot(w0m,color='lightgreen')
plt.title('Normal Data ',fontsize=25,fontname='Comic Sans MS')



ax = fig.add_subplot(222)
sns.boxplot(log_w0m,color='lightblue')
plt.title('Log Transformed Data ',fontsize=25,fontname='Comic Sans MS')


ax = fig.add_subplot(223)
sns.boxplot(w1m,color='lightgreen')

ax = fig.add_subplot(224)
sns.boxplot(log_w1m,color='lightblue')
plt.show()

# %%
fig = plt.figure(figsize=(15,7))

ax = fig.add_subplot(221)
w0m.hist(bins=100)
plt.title('Histplot for normal non-working day data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(222)
stats.probplot(w0m,dist='norm',plot=plt)
plt.title('QQplot for normal non-working day data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(223)
w1m.hist(bins=100)
plt.title('Histplot for normal working day data ',fontsize=15,fontname='Comic Sans MS')



ax = fig.add_subplot(224)
stats.probplot(w1m,dist='norm',plot=plt)
plt.title('QQplot for normal working day data ',fontsize=15,fontname='Comic Sans MS')


plt.subplots_adjust( wspace=0.3, hspace=.5)
plt.show()

# %%
w0m=w0['count']
w0m.mean()
# Out:
# 188.50662061024755

# %%
dof = w0.shape[0] + w1.shape[0] -2
dof
# Out:
# 10884

# %%
w1m.mean() - w0m.mean()
# Out:
# 4.505252028716285

# %%
Tstat,pvalue = stats.ttest_ind(w1m,w0m)
print(f'T Statistics and P Value of above T Test is {Tstat} and {pvalue}.')
# Out:
# T Statistics and P Value of above T Test is 1.2096277376026694 and 0.22644804226361348.

# %% [markdown]
# ```From the above test on log transformed data we can see the P Value is > 5%, Hence we fail to reject null hypothesis Ho.```
#
# ```Without log transformation counts of renting cycles in working day is  equal to non-working day.```

# %% [markdown]
# ## Log Transformed T Test

# %%
log_w0m = np.log10(w0m)
log_w1m = np.log10(w1m)
sns.boxplot(log_w0m)
plt.show()
sns.boxplot(log_w1m)
# Out:
# <AxesSubplot:xlabel='count'>

# %%
fig = plt.figure(figsize=(15,6))

ax = fig.add_subplot(221)
sns.histplot(log_w0m,bins=200,kde=True)
plt.title('Histplot for log transformed non-working day data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(222)
stats.probplot(log_w0m,dist='norm',plot=plt)
plt.title('QQplot for log transformed non-working day data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(223)
sns.histplot(log_w1m,bins=200,kde=True)
plt.title('Histplot for log transformed working day data ',fontsize=15,fontname='Comic Sans MS')




ax = fig.add_subplot(224)
stats.probplot(log_w1m,dist='norm',plot=plt)
plt.title('QQplot for log transformed working day data ',fontsize=15,fontname='Comic Sans MS')


plt.subplots_adjust( wspace=0.3, hspace=.5)
plt.show()

# %%
Tstat1,pvalue1 = stats.ttest_ind(log_w0m,log_w1m)
print(f'T Statistics and P Value of above T Test is {Tstat1} and {pvalue1}.')
# Out:
# Ttest_indResult(statistic=1.8913669049596775, pvalue=0.058601910307550055)

# %% [markdown]
# ```From the above test on log transformed data we can see the P Value is > 5%, Hence we fail to reject null hypothesis Ho.```
#
# ```With log transformation Counts of renting cycles in working day is  equal to non-working day.```

# %%
fig = plt.figure(figsize=(15,6))

ax = fig.add_subplot(221)
sns.histplot(boxcox_w0m,bins=200,kde=True)
plt.title('Histplot for boxcox transformed non-working day data ',fontsize=15,fontname='Comic Sans MS')



ax = fig.add_subplot(222)
stats.probplot(boxcox_w0m,dist='norm',plot=plt)
plt.title('QQplot for boxcox transformed non-working day data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(223)
sns.histplot(boxcox_w1m,bins=200,kde=True)
plt.title('Histplot for boxcox transformed working day data ',fontsize=15,fontname='Comic Sans MS')




ax = fig.add_subplot(224)
stats.probplot(boxcox_w1m,dist='norm',plot=plt)
plt.title('QQplot for boxcox transformed working day data ',fontsize=15,fontname='Comic Sans MS')


plt.subplots_adjust( wspace=0.3, hspace=.5)
plt.show()

# %%
Tstat2,pvalue2 = stats.ttest_ind(boxcox_w0m,boxcox_w1m)
print(f'T Statistics and P Value of above T Test is {Tstat2} and {pvalue2}.')
# Out:
# Ttest_indResult(statistic=-9.700433069624191, pvalue=3.690834732852787e-22)

# %% [markdown]
# ```From the above test on boxcox transformed data we can see the P Value is < 5%, Hence we fail to reject alternative hypothesis Ha.```
#
# ```With boxcox transformation counts of renting cycles in working day is not equal to non-working day.```

# %% [markdown]
# ## End T Test

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Annova Test

# %% [markdown]
# ```ANNOVA to check if No. of cycles rented is similar or different in different 1. weather 2. season (10 points)```

# %%
#df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year date    month
# 0        81        0.0       3          13     16  2011   01  January
# 1        80        0.0       8          32     40  2011   01  January
# 2        80        0.0       5          27     32  2011   01  January
# 3        75        0.0       3          10     13  2011   01  January
# 4        75        0.0       0           1      1  2011   01  January

# %%
df['weather'].value_counts()
# Out:
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: weather, dtype: int64

# %%
weather1 = df[df['weather']==1]['count']
weather2 = df[df['weather']==2]['count']
weather3 = df[df['weather']==3]['count']
weather4 = df[df['weather']==4]['count']

# %%
fig = plt.figure(figsize=(13,20))

ax = fig.add_subplot(421)
sns.histplot(weather1,bins=200,kde=True)
plt.title('Histplot for normal weather data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(422)
stats.probplot(weather1,dist='norm',plot=plt)
plt.title('QQplot for normal weather data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(423)
sns.histplot(weather2,bins=200,kde=True)



ax = fig.add_subplot(424)
stats.probplot(weather2,dist='norm',plot=plt)

ax = fig.add_subplot(425)
sns.histplot(weather3,bins=200,kde=True)



ax = fig.add_subplot(426)
stats.probplot(weather3,dist='norm',plot=plt)

ax = fig.add_subplot(427)
sns.histplot(weather4,bins=200,kde=True)



ax = fig.add_subplot(428)
stats.probplot(weather4,dist='norm',plot=plt)

plt.subplots_adjust( wspace=0.3, hspace=.3)
plt.show()

# %%
from scipy.stats import f_oneway
f, p = f_oneway(weather1, weather2, weather3,weather4)
print(f'F Statistics and P Value of above Anova Test is {f} and {p}.')

# %% [markdown]
# ``` As p value is < alpha ~ 5% , we fail to accept the null hypothesis```

# %% [markdown]
# ```No of cycles renting is not similar in different weathers```

# %% [markdown]
# ## Log Transformed  Weather Anova Test

# %%
log_wea1 = np.log(weather1)
log_wea2 = np.log(weather2)
log_wea3 = np.log(weather3)
log_wea4 = np.log(weather4)

# %%
fig = plt.figure(figsize=(13,20))

ax = fig.add_subplot(421)
sns.histplot(log_wea1,bins=200,kde=True)
plt.title('Histplot for log transformd weather data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(422)
stats.probplot(log_wea1,dist='norm',plot=plt)
plt.title('QQplot for log transformd weather data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(423)
sns.histplot(log_wea2,bins=200,kde=True)



ax = fig.add_subplot(424)
stats.probplot(log_wea2,dist='norm',plot=plt)

ax = fig.add_subplot(425)
sns.histplot(log_wea3,bins=200,kde=True)



ax = fig.add_subplot(426)
stats.probplot(log_wea3,dist='norm',plot=plt)

ax = fig.add_subplot(427)
sns.histplot(log_wea4,bins=200,kde=True)



ax = fig.add_subplot(428)
stats.probplot(log_wea4,dist='norm',plot=plt)

plt.subplots_adjust( wspace=0.3, hspace=.3)
plt.show()

# %%
f1, p1 = f_oneway(log_wea1, log_wea2, log_wea3,log_wea4)
print(f'F Statistics and P Value of above Anova Test is {f1} and {p1}.')
# Out:
# 49.879471483981746
# 5.214500121600914e-32

# %% [markdown]
# ``` As p value is < alpha ~ 5%, we fail to accept null hypothesis```
#
#
#
# ```No of cycles renting is not similar in different weathers```

# %% [markdown]
# # Seasons

# %%
#df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year date    month
# 0        81        0.0       3          13     16  2011   01  January
# 1        80        0.0       8          32     40  2011   01  January
# 2        80        0.0       5          27     32  2011   01  January
# 3        75        0.0       3          10     13  2011   01  January
# 4        75        0.0       0           1      1  2011   01  January

# %%
df['season'].value_counts()
# Out:
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: season, dtype: int64

# %%
season1 = df[df['season']==1]['count']
season2 = df[df['season']==2]['count']
season3 = df[df['season']==3]['count']
season4 = df[df['season']==4]['count']

# %%
fig = plt.figure(figsize=(13,20))

ax = fig.add_subplot(421)
sns.histplot(season1,bins=200,kde=True)
plt.title('Histplot for normal season data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(422)
stats.probplot(season1,dist='norm',plot=plt)
plt.title('QQplot for normal season data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(423)
sns.histplot(season2,bins=200,kde=True)



ax = fig.add_subplot(424)
stats.probplot(season2,dist='norm',plot=plt)

ax = fig.add_subplot(425)
sns.histplot(season3,bins=200,kde=True)



ax = fig.add_subplot(426)
stats.probplot(season3,dist='norm',plot=plt)

ax = fig.add_subplot(427)
sns.histplot(season4,bins=200,kde=True)



ax = fig.add_subplot(428)
stats.probplot(season4,dist='norm',plot=plt)

plt.subplots_adjust( wspace=0.3, hspace=.3)
plt.show()

# %%
from scipy.stats import f_oneway
f2, p2 = f_oneway(season1, season2, season3,season4)
print(f'F Statistics and P Value of above Anova Test is {f2} and {p2}.')
# Out:
# 236.94671081032106
# 6.164843386499654e-149

# %% [markdown]
# ``` As p value is < alpha~5%, we fail to accept null hypothesis```
#
#
#
# ```No of cycles renting is not similar in different seasons```

# %% [markdown]
# ## Log Transformed  Seasons Anova Test

# %%
log_sea1 = np.log(season1)
log_sea2 = np.log(season2)
log_sea3 = np.log(season3)
log_sea4 = np.log(season4)

# %%
fig = plt.figure(figsize=(13,20))

ax = fig.add_subplot(421)
sns.histplot(log_sea1,bins=200,kde=True)
plt.title('Histplot for log transformd season data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(422)
stats.probplot(log_sea1,dist='norm',plot=plt)
plt.title('QQplot for log transformd sason data ',fontsize=15,fontname='Comic Sans MS')


ax = fig.add_subplot(423)
sns.histplot(log_sea2,bins=200,kde=True)



ax = fig.add_subplot(424)
stats.probplot(log_sea2,dist='norm',plot=plt)

ax = fig.add_subplot(425)
sns.histplot(log_sea3,bins=200,kde=True)



ax = fig.add_subplot(426)
stats.probplot(log_sea3,dist='norm',plot=plt)

ax = fig.add_subplot(427)
sns.histplot(log_sea4,bins=200,kde=True)



ax = fig.add_subplot(428)
stats.probplot(log_sea4,dist='norm',plot=plt)

plt.subplots_adjust( wspace=0.3, hspace=.3)
plt.show()

# %%
f3, p3 = f_oneway(log_sea1, log_sea2, log_sea3,log_sea4)
print(f'F Statistics and P Value of above Anova Test is {f3} and {p3}.')
# Out:
# 138.85324276733598
# 1.0578890307202768e-87

# %% [markdown]
# ``` As p value is < alpha ~ 5%, we fail to accept null hypothesis```
#
#
#
# ```No of cycles renting is not similar in different seasons```

# %% [markdown]
# ## Annova Test End

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Chi-Sq Test

# %% [markdown]
# ``Formula -: (Observed Value - Expected Value)² / Expected Value.``

# %% [markdown]
# - ```check if Weather is dependent on the season```

# %%
chi_tab = pd.crosstab(df.weather,df.season,values=df['count'],aggfunc=sum)
chi_tab
# Out:
# season          1         2         3         4
# weather
# 1        223009.0  426350.0  470116.0  356588.0
# 2         76406.0  134177.0  139386.0  157191.0
# 3         12919.0   27755.0   31160.0   30255.0
# 4           164.0       NaN       NaN       NaN

# %% [markdown]
# #### -    As last row have less than 20 % data with respect to to overall dataset, according to chi sq assumtion the row is removed.

# %%
chi_tab.loc[1:3]
# Out:
# season          1         2         3         4
# weather
# 1        223009.0  426350.0  470116.0  356588.0
# 2         76406.0  134177.0  139386.0  157191.0
# 3         12919.0   27755.0   31160.0   30255.0

# %%
stat, p_value, dof, expected = stats.chi2_contingency(chi_tab.loc[1:3])
stat, p_value, dof
print(f'T Statistics and P Value of above Chi Sq Test is {stat} and {p_value}.')
# Out:
# (10838.372332480216, 0.0, 6)

# %% [markdown]
# ```As chi sq p value  < alpha, we fail to accept null hypothesis```
#
#
# ```It can be concluded that weather and season are dependent, Null Hypothesis Ho is rejected```

# %%
norm.ppf(1-.05)
# Out:
# 1.6448536269514722

# %%
norm.ppf(.05)
# Out:
# -1.6448536269514729

# %% [markdown]
# ## Log-Likelihood

# %%
from bioinfokit.analys import stat
res = stat()
res.chisq(df = chi_tab.loc[1:3,1:4])
print(res.summary)
# Out:
# Chi-squared test for independence
#
# Test              Df    Chi-square    P-value
# --------------  ----  ------------  ---------
# Pearson            6       10838.4          0
# Log-likelihood     6       10691.1          0

# %% [markdown]
# ```Both normal chi sq and log transformed chi sq p value is not significant enough to accept null hypothesis```
#
#
# ```It can be concluded that weather and season are dependent, Null Hypothesis Ho is rejected```

# %%
# x = pd.pivot_table(df,index='weather', columns = 'season',values = 'count')
# x
# x = x.loc[1:3]
# x

# %% [markdown]
# ## Chi- Square Test Ends.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## ..................................................................................X....................END..............................X...................................................................................

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
