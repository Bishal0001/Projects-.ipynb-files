# %% [markdown]
# ## Business Case: LoanTap Logistic Regression
#
#
#
#
# Project Subbmission Date : **18 Nov 22**
#
#
#
# **Context :**
#
# ``LoanTap is an online platform committed to delivering customized loan products to millennials. They innovate in an otherwise dull loan segment, to deliver instant, flexible loans on consumer friendly terms to salaried professionals and businessmen.``
#
# ``The data science team at LoanTap is building an underwriting layer to determine the creditworthiness of MSMEs as well as individuals.``
#
# **LoanTap deploys formal credit to salaried individuals and businesses 4 main financial instruments :**
#
# - Personal Loan
#
#
# - EMI Free Loan
#
#
# - Personal Overdraft
#
#
# - Advance Salary Loan
#
#
#
# This case study will focus on the underwriting process behind Personal Loan only
#
# **Problem Statement :**
#
# ``Given a set of attributes for an Individual, determine if a credit line should be extended to them. If so, what should the repayment terms be in business recommendations?``
#
# Dataset: LoanTapData.csv
#
# ### ***Data dictionary :***
#
# - **loan_amnt** : The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
#
#
# - **term :** The number of payments on the loan. Values are in months and can be either 36 or 60.
#
#
#
# - **int_rate :** Interest Rate on the loan
#
#
#
# - **installment :** The monthly payment owed by the borrower if the loan originates.
#
#
#
# - **grade :** LoanTap assigned loan grade
#
#
#
# - **sub_grade :** LoanTap assigned loan subgrade
#
#
#
# - **emp_title :** The job title supplied by the Borrower when applying for the loan.*
#
#
#
# - **emp_length :** Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
#
#
#
# - **home_ownership :** The home ownership status provided by the borrower during registration or obtained from the credit report.
#
#
#
# - **annual_inc :** The self-reported annual income provided by the borrower during registration.
#
#
# - **verification_status :** Indicates if income was verified by LoanTap, not verified, or if the income source was verified
#
#
#
# - **issue_d :** The month which the loan was funded
#
#
#
# - **loan_status :** Current status of the loan - **<---   Target Variable**
#
#
#
# - **purpose :** A category provided by the borrower for the loan request.
#
#
#
# - **title :** The loan title provided by the borrower
#
#
# - **dti :** A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LoanTap loan, divided by the borrower’s self-reported monthly income.
#
#
#
# - **earliest_cr_line :** The month the borrower's earliest reported credit line was opened
#
#
#
# - **open_acc :** The number of open credit lines in the borrower's credit file.
#
#
#
# - **pub_rec :** Number of derogatory public records
#
#
#
# - **revol_bal :** Total credit revolving balance
#
#
#
# - **revol_util :** Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
#
#
# - **total_acc :** The total number of credit lines currently in the borrower's credit file
#
#
#
# - **initial_list_status :** The initial listing status of the loan. Possible values are – W, F
#
#
#
# - **application_type :** Indicates whether the loan is an individual application or a joint application with two co-borrowers
#
#
#
#
# - **mort_acc :** Number of mortgage accounts.
#
#
#
# - **pub_rec_bankruptcies :** Number of public record bankruptcies
#
#
#
#
# - **Address:** Address of the individual
#
#
#
#
#
# ### ***Concept Used :***
#
# - Exploratory Data Analysis
#
#
# - Feature Engineering
#
#
# - Logistic Regression
#
#
# - Precision Vs Recall Tradeoff
#
#
# **What does ‘good’ look like?**
#
# ```Import the dataset and do usual exploratory data analysis steps like checking the structure & characteristics of the dataset```
#
#
# ``Check how much target variable (Loan_Status) depends on different predictor variables (Use count plots, box plots, heat maps etc)``
#
#
# ``Check correlation among independent variables and how they interact with each other``
#
#
#
# ```Simple Feature Engineering steps:```
# ```E.g.: Creation of Flags- If value greater than 1.0 then 1 else 0. This can be done on:```
# ```1. Pub_rec```
# ```2. Mort_acc```
# ```3. Pub_rec_bankruptcies```
#
# ``Missing values and Outlier Treatment``
#
# ``Scaling - Using MinMaxScaler or StandardScaler``
#
# **Use Logistic Regression Model from Sklearn/Statsmodel library and explain the results
# Results Evaluation:**
#
#
# - Classification Report
#
#
# - ROC AUC curve
#
#
# - Precision recall curve
#
#
# ***Tradeoff Questions :***
#
# - How can we make sure that our model can detect real defaulters and there are less false positives? This is important as we can lose out on an opportunity to finance more individuals and earn interest on it.
#
#
# - Since NPA (non-performing asset) is a real problem in this industry, it’s important we play safe and shouldn’t disburse loans to anyone
#
#
# - Provide actionable Insights & Recommendations
#
#
#
#
# ### ***Evaluation Criteria (100 points)***
#
# **Define Problem Statement and perform Exploratory Data Analysis (10 points)**
#
#
# - Definition of problem (as per given problem statement with additional views)
#
#
# - Observations on shape of data, data types of all the attributes, conversion of categorical attributes to 'category' (If required), missing value detection, statistical summary.
#
#
# - Univariate Analysis (distribution plots of all the continuous variable(s) barplots/countplots of all the categorical variables)
#
#
# - Bivariate Analysis (Relationships between important variable)
#
#
# -  Illustrate the insights based on EDA
#
#
# - Comments on range of attributes, outliers of various attributes
#
#
# - Comments on the distribution of the variables and relationship between them
#
#
# - Comments for each univariate and bivariate plots
#
#
#
# **Data Preprocessing (20 Points)**
#
#
#
# - Duplicate value check
#
#
# - Missing value treatment
#
#
# - Outlier treatment
#
#
# - Feature engineering
#
#
# - Data preparation for modeling
#
#
#
# **Model building (10 Points)**
#
#
#
# - Build the Logistic Regression model and comment on the model statistics
#
#
# - Display model coefficients with column names
#
#
# **Results Evaluation (50 Points)**
#
#
#
# - ROC AUC Curve & comments (10 Points)
#
#
# - Precision Recall Curve & comments (10 Points)
#
#
# - Classification Report (Confusion Matrix etc) (10 Points)
#
#
# ***Tradeoff Questions:***
#
#
# - How can we make sure that our model can detect real defaulters and there are less false positives? This is important as we can lose out on an opportunity to finance more individuals and earn interest on it. (10 Points)
#
#
#
# - Since NPA (non-performing asset) is a real problem in this industry, it’s important we play safe and shouldn’t disburse loans to anyone. (10 Points)
#
#
# - Actionable Insights & Recommendations (10 Points)
#
#
#
#
# ### ***Questionnaire (Answers should present in the text editor along with insights):***
#
# 1) What percentage of customers have fully paid their Loan Amount?
#
#
# 2) Comment about the correlation between Loan Amount and Installment features.
#
#
# 3) The majority of people have home ownership as _______.
#
#
# 4) People with grades ‘A’ are more likely to fully pay their loan. (T/F)
#
#
# 5) Name the top 2 afforded job titles.
#
#
# ***Thinking from a bank's perspective, which metric should our primary focus be on..***
#
#
# - ROC AUC
#
#
# - Precision
#
#
# - Recall
#
#
# - F1 Score
#
#
# How does the gap in precision and recall affect the bank?
#
#
# Which were the features that heavily affected the outcome?
#
#
# Will the results be affected by geographical location? (Yes/No)
#
#
# Discussion forum link: https://www.scaler.com/academy/mentee-dashboard/discussion-forum/p/ask-me-anything-business-case-loantap/21146
#
#
# **Submission Process:**
#
# ``Type Recommendations and Questionnaire answers in the text editor
# Convert your jupyter notebook into PDF (Save as PDF using Chrome browser’s Print command), upload it in your Google Drive (set the permission to allow public access), and paste that link in the text editor
# Optionally, you may add images/graphs in the text editor by taking screenshots or saving matplotlib graphs using plt.savefig(...)``
# ``After submitting, you will not be allowed to edit your submission``

# %% [markdown]
# ---
# ## Project Starts Here
# ---

# %%
import pandas as pd
import numpy as np 
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import datetime as dt

# %%
df = pd.read_csv('logistic_regression.csv')
df1 = pd.read_csv('logistic_regression.csv')

# %%
# checking shape 

df.shape
# Out:
# (396030, 27)

# %%
# null value in prcentage 

df.isnull().mean()
# Out:
# loan_amnt               0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# sub_grade               0.000000
# emp_title               0.057892
# emp_length              0.046211
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# purpose                 0.000000
# title                   0.004431
# dti                     0.000000
# earliest_cr_line        0.000000
# open_acc                0.000000
# pub_rec                 0.000000
# revol_bal               0.000000
# revol_util              0.000697
# total_acc               0.000000
# initial_list_status     0.000000
# application_type        0.000000
# mort_acc                0.095435
# pub_rec_bankruptcies    0.001351
# address                 0.000000
# dtype: float64

# %%
# checking datatypes

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %%
columns = ['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
       'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
       'verification_status', 'issue_d', 'loan_status', 'purpose', 'title',
       'dti', 'earliest_cr_line', 'open_acc', 'pub_rec', 'revol_bal',
       'revol_util', 'total_acc', 'initial_list_status', 'application_type',
       'mort_acc', 'pub_rec_bankruptcies', 'address']

# %%
# object features

print('Objects Features')
print('_'*17)
objects = df.describe(include='object').columns
objects
# Out:
# Objects Features
# _________________
# Index(['term', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'purpose', 'title', 'earliest_cr_line', 'initial_list_status',
#        'application_type', 'address'],
#       dtype='object')

# %%
# float features

print('Float Features')
print('_'*17)
floats = df.describe(include='float').columns
floats
# Out:
# Float Features
# _________________
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'mort_acc',
#        'pub_rec_bankruptcies'],
#       dtype='object')

# %%
#describe datatypes other than objects.

df.describe(exclude=object)
# Out:
#            loan_amnt       int_rate    installment    annual_inc  \
# count  396030.000000  396030.000000  396030.000000  3.960300e+05
# mean    14113.888089      13.639400     431.849698  7.420318e+04
# std      8357.441341       4.472157     250.727790  6.163762e+04
# min       500.000000       5.320000      16.080000  0.000000e+00
# 25%      8000.000000      10.490000     250.330000  4.500000e+04
# 50%     12000.000000      13.330000     375.430000  6.400000e+04
# 75%     20000.000000      16.490000     567.300000  9.000000e+04
# max     40000.000000      30.990000    1533.810000  8.706582e+06
#
#                  dti       open_acc        pub_rec     revol_bal  \
# count  396030.000000  396030.000000  396030.000000  3.960300e+05
# mean       17.379514      11.311153       0.178191  1.584454e+04
# std        18.019092       5.137649       0.530671  2.059184e+04
# min         0.000000       0.000000       0.000000  0.000000e+00
# ...

# %%
#describe  objects.

df.describe(include=object)
# Out:
#               term   grade sub_grade emp_title emp_length home_ownership  \
# count       396030  396030    396030    373103     377729         396030
# unique           2       7        35    173105         11              6
# top      36 months       B        B3   Teacher  10+ years       MORTGAGE
# freq        302005  116018     26655      4389     126041         198348
#
#        verification_status   issue_d loan_status             purpose  \
# count               396030    396030      396030              396030
# unique                   3       115           2                  14
# top               Verified  Oct-2014  Fully Paid  debt_consolidation
# freq                139563     14846      318357              234507
#
#                      title earliest_cr_line initial_list_status  \
# count               394275           396030              396030
# unique               48817              684                   2
# ...

# %%
df[[
    'loan_amnt', 'int_rate', 'installment', 'open_acc', 'total_acc',
    'mort_acc', 'grade', 'sub_grade', 'revol_util'
]].hist(bins=20, figsize=(15, 15), color='lightgreen')
plt.show()

# %% [markdown]
# ### Observation 1
# ---
#
# - There are very least low grade loans.
#
#
# - There are very least low subgrade loans.
#
#
# - Most loan amounts are above 15000.
#
#
#
# - Most of the interest rates are between 8 - 18.
#
#
#
# - Most of the installments are between 200 - 500.

# %% [markdown]
# ## Probability Plots.
# ---

# %%
def cond_prob(i, j):
    Joint_vals_fitness = pd.crosstab(i, j, normalize=True)
    product = Joint_vals_fitness.sum(axis=0)
    cond_Prob = Joint_vals_fitness.divide(product, axis=1)
    return cond_Prob.plot.bar(
        figsize=(15, 7),
        grid=True,
        color=('black', 'gold', 'chartreuse', 'r', 'm', 'darkorange',
               'dimgrey', 'c', 'yellow', 'deeppink', 'moccasin',
               'midnightblue', 'olivedrab', 'olive', 'palegreen', 'powderblue',
               'mediumvioletred', 'beige', 'khaki', 'firebrick',
               'floralwhite', 'forestgreen', 'fuchsia', 'gainsboro',
               'ghostwhite', 'goldenrod', 'gray', 'green',
               'greenyellow', 'honeydew', 'hotpink', 'indianred', 'indigo',
               'ivory', 'khaki', 'lavender', 'lavenderblush', 'lawngreen',
               'lemonchiffon', 'lightblue', 'lightcoral', 'lightcyan',
               'lightgoldenrodyellow', 'lightgreen', 'lightgray', 'lightpink',
               'lightsalmon', 'lightseagreen', 'lightskyblue',
               'lightslategray', 'lightsteelblue', 'lightyellow', 'lime',
               'limegreen', 'linen', 'magenta', 'maroon', 'mediumaquamarine',
               'mediumblue', 'mediumorchid', 'mediumpurple', 'mediumseagreen',
               'mediumslateblue', 'mediumspringgreen', 'mediumturquoise',
               'mediumvioletred', 'midnightblue', 'mintcream', 'mistyrose',
               'moccasin', 'navajowhite', 'navy', 'oldlace', 
               'olivedrab'))

# %%
cond_prob(df.term ,df.loan_status)
plt.title(
'Probability of loan terms according to loan status',
fontsize=16,
fontname='Comic Sans MS')
plt.show()

# %% [markdown]
# ### Observation 2
# ---
#
# - 80% of fully paid loans are on 36 months terms.
#
#
# - 60% of charged off loans are on 36 months term.
#
#
#
#
# - When loan terms exceded to 60 months probability of charged off gets increased.

# %%
cond_prob(df.loan_status ,df.grade )
plt.title(
'Probability of loan status according to loan grades',
fontsize=16,
fontname='Comic Sans MS')
plt.show()

# %% [markdown]
# ### Observation 3
# ---
#
# - Probability of fully paid grade A loans are above 90%.
#
#
# - As grade increases probability of fully paid loans get decreases.
#
#
#
# - Probability of paying grade G loan is least with nearly 57% approx.

# %%
cond_prob(df.loan_status ,df.sub_grade  )
plt.title(
'Probability of loan status according to subgrades',
fontsize=16,
fontname='Comic Sans MS')
plt.legend(loc="center", mode = "expand", ncol = 6)
plt.show()

# %% [markdown]
# ### Observation 4
# ---
#
# - As subgrade increases probability of fully paid loans get decreases.
#
#
# - The least quality loan is of G5 grade with paying probability of approx 50%.
#
#
#
# - The highest quality loan is of A1 grade with paying probability of above 90%.

# %%
cond_prob(df.loan_status ,df.emp_length   )
plt.title(
'Probability of loan status according to employement length of an employee',
fontsize=16,
fontname='Comic Sans MS')
plt.legend(loc="center", mode = "expand", ncol = 3)
plt.show()

# %% [markdown]
# ### Observation 5
# ---
#
# - According to employment length above or equal to 1 year, probability of paying loans are more than making defaults.

# %%
cond_prob(df.loan_status ,df.home_ownership    )
plt.title(
'Probability of loan status according to home ownership',
fontsize=16,
fontname='Comic Sans MS')
plt.legend(loc="upper left", ncol = 1)
plt.show()

# %% [markdown]
# ### Observation 6
# ---
#
# - Probability of paying loans according to home ownership is nearly 80%.

# %%
cond_prob(df.loan_status ,df.verification_status)
plt.title(
'Probability of loan status according to verification status',
fontsize=16,
fontname='Comic Sans MS')
plt.legend(loc="upper left", ncol = 1)
plt.show()

# %% [markdown]
# ### Observation 7
# ---
#
# - Probability of paying loans is the highest with above 80% when not verified.

# %%
cond_prob(df.loan_status ,df.purpose )
plt.title(
'Probability of loan status according to loan purpouse',
fontsize=16,
fontname='Comic Sans MS')
plt.legend(loc="upper left", ncol = 1)
plt.show()

# %% [markdown]
# ### Observation 8
# ---
#
# - Loans that are taken for cars and weddings have the highest probability of paying back.
#
#
# - Loans that are taken for small businesses have the least probability of paying back.

# %%
cond_prob(df.loan_status ,df.pub_rec  )
plt.title(
'Probability of loan status according to number of derogatory public records',
fontsize=16,
fontname='Comic Sans MS')
plt.legend(loc="upper left", ncol = 1)
plt.show()

# %% [markdown]
# ### Observation 9
# ---
#
# - Loans that have 12,19,40,86 numbers of derogatory records are 100% likely to make a default.
#
#
# - Loans that have 15,17,24 numbers of derogatory records are 100% probability of paying back the loans.

# %%
cond_prob(df.loan_status ,df.initial_list_status   )
plt.title(
'Probability of loan status according to initial list status',
fontsize=16,
fontname='Comic Sans MS')
plt.legend(loc="upper left", ncol = 1)
plt.show()

# %% [markdown]
# ### Observation 8
# ---
#
# - Probability of fully paid loans are more according to initial list status.

# %%
cond_prob(df.loan_status ,df.application_type    )
plt.title(
'Probability of loan status according to application status',
fontsize=16,
fontname='Comic Sans MS')
# plt.legend(loc='best')
plt.legend(loc="upper left", ncol = 1)
plt.show()

# %% [markdown]
# ### Observation 9
# ---
#
# - Joint loans are most likely to get fully paid with probability of above 80%.
#
#
# - Individual loans have 80% probability of paying back.
#
#
# - Direct paying loans have least probability of paying back with nearly 38%.

# %%
cond_prob(df.loan_status ,df.pub_rec_bankruptcies      )
plt.title(
'Probability of loan status according to number of public record bankruptcies',
fontsize=16,
fontname='Comic Sans MS')
plt.legend(loc="upper left", ncol = 1)
plt.show()

# %% [markdown]
# ### Observation 10
# ---
#
# - Loans that have 8 numbers of public records bankruptcies have least probabillity of paying back with 50%.
#
#
# - Loans that have 5 numbers of public records bankruptcies have highest probabillity of paying back with nearly 83%.

# %%
cond_prob(C.loan_status ,C.int_catagory      )
plt.title(
'Probability of loan status according to number of public record bankruptcies',
fontsize=16,
fontname='Comic Sans MS')
plt.legend(loc="upper left", ncol = 1)
plt.show()

# %% [markdown]
# ### Observation
# ---
# **Fully Paid ~ 1**
#
# **Charged Off ~ 0**
#
#
# - Loans that has 20 - 25 interest rates have least probablity(61%) of paying back loans.
#
#
# - Loans that has 5 - 10 interest rates have highest probablity(> 90%) of paying back loans.

# %% [markdown]
# ## Probability Plots End.
# ---

# %% [markdown]
# ## Encoding Data( Converting catagorical to numericle )
# ---

# %%
df['loan_status'] = df['loan_status'].map({'Fully Paid':1, 'Charged Off':0})
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec  revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0    36369.0       41.8      25.0                    w
# ...

# %%
df.int_catagory.value_counts()
# Out:
# 10-15    104157
# 15-20     68111
# 5-10      57599
# 20-25     19018
# Name: int_catagory, dtype: int64

# %%
target_enc = [
    'term', 'emp_title', 'emp_length', 'home_ownership', 'verification_status',
    'issue_d', 'loan_status', 'purpose', 'title', 'earliest_cr_line',
    'initial_list_status', 'application_type', 'address'
]

# %%
for col in target_enc:
    from category_encoders import TargetEncoder
    TEncoder = TargetEncoder()
    
    df[col] = TEncoder.fit_transform(df[col],df["loan_status"])

# %%
df.head()
# Out:
#    loan_amnt      term  int_rate  installment  grade  sub_grade  emp_title  \
# 0    10000.0  0.842254     11.44       329.48    5.0       26.0   0.752809
# 1     8000.0  0.842254     11.99       265.68    5.0       25.0   0.683022
# 2    15600.0  0.842254     10.49       506.97    5.0       27.0   0.818181
# 3     7200.0  0.842254      6.49       220.65    6.0       33.0   0.803871
# 4    24375.0  0.680585     17.27       609.33    4.0       20.0   0.803871
#
#    emp_length  home_ownership  annual_inc  ...  earliest_cr_line  open_acc  \
# 0    0.815814        0.773378    117000.0  ...          0.847458      16.0
# 1    0.807615        0.830439     65000.0  ...          0.769937      17.0
# 2    0.793128        0.773378     43057.0  ...          0.780709      13.0
# 3    0.810806        0.773378     54000.0  ...          0.774317       6.0
# 4    0.799530        0.830439     55000.0  ...          0.807872      13.0
#
# ...

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title                   0
# emp_length                  0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                       0
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# dtype: int64

# %% [markdown]
# ## Ordinal Encoding
# ---

# %%
from sklearn.preprocessing import OrdinalEncoder

label_grade = sorted(df.grade.unique())[::-1]
label_sgrade = sorted(df.sub_grade.unique())[::-1]

# %%
ord_enc = OrdinalEncoder(categories = [label_grade])
ord_enc1 = OrdinalEncoder(categories = [label_sgrade])

ord_enc.fit(df[['grade']])
ord_enc1.fit(df[['sub_grade']])


df['grade'] = ord_enc.transform(df[['grade']])
df['sub_grade'] = ord_enc1.transform(df[['sub_grade']])

# %%
df.head()
# Out:
#    loan_amnt      term  int_rate  installment  grade  sub_grade  emp_title  \
# 0    10000.0  0.842254     11.44       329.48    5.0       26.0   0.752809
# 1     8000.0  0.842254     11.99       265.68    5.0       25.0   0.683022
# 2    15600.0  0.842254     10.49       506.97    5.0       27.0   0.818181
# 3     7200.0  0.842254      6.49       220.65    6.0       33.0   0.803871
# 4    24375.0  0.680585     17.27       609.33    4.0       20.0   0.803871
#
#    emp_length  home_ownership  annual_inc  ...  open_acc  pub_rec  revol_bal  \
# 0    0.815814        0.773378    117000.0  ...      16.0      0.0    36369.0
# 1    0.807615        0.830439     65000.0  ...      17.0      0.0    20131.0
# 2    0.793128        0.773378     43057.0  ...      13.0      0.0    11987.0
# 3    0.810806        0.773378     54000.0  ...       6.0      0.0     5472.0
# 4    0.799530        0.830439     55000.0  ...      13.0      0.0    24584.0
#
# ...

# %% [markdown]
# ## Ordinal Encoding Ends.

# %% [markdown]
# ## Encoding Ends.
# ---

# %% [markdown]
# ## Outlier Handling Starts Here.
# ---

# %%
df_trans = df.copy()

# %%
X3 = df_trans.loc[:,df_trans.columns!='loan_status']
y3 = df_trans.loan_status
X3 = X3.drop(['pub_rec_bankruptcies'], axis=1)


X3['ultimate_grade'] = np.round(
    np.sqrt(X3.grade * X3.sub_grade * X3.emp_title * X3.issue_d ), 2)

X3['time_to_pay'] = np.round(X3.loan_amnt/X3.installment,2)
X3['loan_inc_ratio'] = np.round((X3.loan_amnt*1000/X3.annual_inc)**2,2)
X3['fuss'] = np.round((
    (X3.loan_amnt * X3.int_rate) /
    ( X3.installment * X3.term))**2,2)




X3.total_acc.fillna(np.mean(X3.total_acc),inplace=True)
X3.revol_util.fillna(np.mean(X3.revol_util),inplace=True)
X3.mort_acc.fillna(np.mean(X3.mort_acc),inplace=True)



X3 = X3.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)

# %%
# This function will return outlier lss dataframe.
def outlier_remover(a,df):

    q1 = a.quantile(.25)
    q3 = a.quantile(.75)
    iqr = q3 - q1

    maxx = q3 + 1.5 * iqr
    minn = q1 - 1.5 * iqr

    return df.loc[(a>=minn) & (a<=maxx)]

# %%
floats
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'mort_acc',
#        'pub_rec_bankruptcies'],
#       dtype='object')

# %%
for i in floats:
    df = outlier_remover(df[i],df)

# %%
for i in floats:
    plt.figure(figsize=(15, 3))
    plt.subplot(121)
    sns.boxplot(y=df1[i], color='chartreuse')
    plt.title(f"Boxplot of {i} before removing outliers", fontsize=15, fontname='Comic Sans MS')
    plt.subplot(122)
    sns.boxplot(y=df[i], color='midnightblue')
    plt.title(f"Boxplot of {i} after removing outliers",
              fontsize=15,
              fontname='Comic Sans MS')

    plt.show()

# %% [markdown]
# ### Observation 11
# ---
#
# - The range of most of the features got reduced multiple folds after removal of outliers

# %%
#null value percentage 
df1.isnull().sum().sum() / len(df1)
# Out:
# 0.20601722091760724

# %%
print(df.shape)
df.head()
# Out:
# (249061, 27)
#    loan_amnt      term  int_rate  installment  grade  sub_grade  emp_title  \
# 0    10000.0  0.842254     11.44       329.48    5.0       26.0   0.752809
# 1     8000.0  0.842254     11.99       265.68    5.0       25.0   0.683022
# 2    15600.0  0.842254     10.49       506.97    5.0       27.0   0.818181
# 3     7200.0  0.842254      6.49       220.65    6.0       33.0   0.803871
# 4    24375.0  0.680585     17.27       609.33    4.0       20.0   0.803871
#
#    emp_length  home_ownership  annual_inc  ...  open_acc  pub_rec  revol_bal  \
# 0    0.815814        0.773378    117000.0  ...      16.0      0.0    36369.0
# 1    0.807615        0.830439     65000.0  ...      17.0      0.0    20131.0
# 2    0.793128        0.773378     43057.0  ...      13.0      0.0    11987.0
# 3    0.810806        0.773378     54000.0  ...       6.0      0.0     5472.0
# 4    0.799530        0.830439     55000.0  ...      13.0      0.0    24584.0
#
# ...

# %%
# 37% of data got lost in outlier removal part
(df1.shape[0] - df.shape[0])/df1.shape[0]
# Out:
# 0.3711057243138146

# %% [markdown]
# ## Outlier Handling Part Ends.
# ---

# %%
floats
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'mort_acc',
#        'pub_rec_bankruptcies'],
#       dtype='object')

# %%
df = df.drop(['pub_rec', 'pub_rec_bankruptcies'], axis=1)

# %%
C = pd.concat([X3,y3],axis=1)
# Out:
#    loan_amnt      term  int_rate  installment  grade  sub_grade  emp_title  \
# 0    10000.0  0.842254     11.44       329.48    5.0       26.0   0.752809
# 1     8000.0  0.842254     11.99       265.68    5.0       25.0   0.683022
# 2    15600.0  0.842254     10.49       506.97    5.0       27.0   0.818181
# 3     7200.0  0.842254      6.49       220.65    6.0       33.0   0.803871
# 4    24375.0  0.680585     17.27       609.33    4.0       20.0   0.803871
#
#    emp_length  home_ownership  annual_inc  ...  total_acc  \
# 0    0.815814        0.773378    117000.0  ...       25.0
# 1    0.807615        0.830439     65000.0  ...       27.0
# 2    0.793128        0.773378     43057.0  ...       26.0
# 3    0.810806        0.773378     54000.0  ...       13.0
# 4    0.799530        0.830439     55000.0  ...       43.0
#
#    initial_list_status  application_type  mort_acc   address  ultimate_grade  \
# 0             0.799245          0.803913       0.0  0.803871            8.56
# ...

# %%
C['int_catagory'] = pd.cut(C.int_rate,bins=[5,10,15,20,25],labels=['5-10','10-15','15-20','20-25'])

# %%
from category_encoders import TargetEncoder
TEncoder1 = TargetEncoder()

C['int_catagory'] = TEncoder1.fit_transform(C['int_catagory'],C["loan_status"])

# %%
# correlation plot.

plt.figure(figsize=(24,15))
sns.heatmap(C.corr(),annot=True,cmap='BrBG_r')
plt.title(
    'Correlation plot using heatmap (including engineered features like time_to_pay,ultimate_grade,loan_inc_ratio,fuss)',
    fontsize=18,
    fontname='Comic Sans MS')
plt.show()

# %% [markdown]
# ### Observation 12
# ---
#
# - Loan Status is our target variable.
#
#
# - Target variable has highest positive correlation with ultimate grade which is an engineered feature which signifies the better the grade the better the chances of paying back loans.
#
#
# - Target variable has highest negetive correlation with interest rate which signifies chance of not paying loans as interest rates increases.
#
#
# - Target variable has good positive correlation with employee title.
#
#
#
#
# - Target variable has good positive correlation with both grades and subgrades, which signifies the more the grade the better chance of paying loan back.
#
#
# - Engineered feature interest catagory(int_catagory) have a good positive correaltion with target variable.

# %%
df.head()
# Out:
#         loan_amnt      term  int_rate  installment  grade  sub_grade  \
# 0         10000.0  0.842254     11.44       329.48    5.0       26.0
# 1          8000.0  0.842254     11.99       265.68    5.0       25.0
# 2         15600.0  0.842254     10.49       506.97    5.0       27.0
# 3          7200.0  0.842254      6.49       220.65    6.0       33.0
# 4         24375.0  0.680585     17.27       609.33    4.0       20.0
# ...           ...       ...       ...          ...    ...        ...
# 396023    22000.0  0.842254     18.92       805.55    3.0       16.0
# 396024     6000.0  0.842254     13.11       202.49    5.0       26.0
# 396025    10000.0  0.680585     10.99       217.38    5.0       26.0
# 396027     5000.0  0.842254      9.99       161.32    5.0       29.0
# 396028    21000.0  0.680585     15.31       503.02    4.0       23.0
#
#         emp_title  emp_length  home_ownership  annual_inc  ...    dti  \
# ...

# %%
df['loan_status'].value_counts(normalize=True)
# Out:
# 1    0.799391
# 0    0.200609
# Name: loan_status, dtype: float64

# %% [markdown]
# ## Model trained on non-outlier data.
# ---

# %%
X = df.loc[:, df.columns != 'loan_status']
y = df.loan_status

# %%
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
y_train.value_counts()
# Out:
# 1    159297
# 0     39951
# Name: loan_status, dtype: int64

# %%
logreg_model = LogisticRegression(C=0.1,max_iter=100)
logreg_model.fit(X_train,y_train)


logreg_model_coef = logreg_model.coef_
logreg_model_intercept = logreg_model.intercept_



print('intercept : ',logreg_model.intercept_,'\n')
print('coefficients : ',logreg_model.coef_,'\n')
# Out:
# intercept :  [0.00100172]
#
# coefficients :  [[-8.11699317e-05  1.02676087e-03 -1.29855231e-02  2.40260162e-03
#    1.27264271e-02  6.62795046e-02  2.03185912e-03  8.25486562e-04
#    8.46779354e-04  7.63587265e-06  9.09803043e-04  1.04703175e-03
#    8.43443608e-04  1.15425034e-03 -1.33403397e-02  8.37594013e-04
#   -2.05983524e-03 -5.20456622e-06 -2.58168392e-03  5.83325327e-03
#    8.05098843e-04  8.06264993e-04  2.86516777e-03  8.72173480e-04]]

# %%
values = []
x_pos = []
for col in X.columns:
    values.append(col)
    
values1 = np.array(values).reshape(-1,1)
pos1 = logreg_model_coef[0].reshape(-1,1)
df_mod = pd.DataFrame(np.concatenate((values1,pos1),axis=1),columns=['feature','coef'])
df_mod['coef']=df_mod['coef'].astype(float)

plt.figure(figsize=(13,6))
sns.barplot(data= df_mod,x='feature',y='coef')

plt.xticks(rotation=90)
plt.title(
    'Feature weights for simple logistic regression model',
    fontsize=18,
    fontname='Comic Sans MS')
plt.grid()
plt.show()

# %% [markdown]
# ### observation 13
# ---
#
# - Using simple imbalanced data model training we can observe that subgrade has best weights among all the features.

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import recall_score,precision_score,roc_auc_score
from sklearn.metrics import f1_score


y_pred1 = logreg_model.predict(X_test)

print('Train Score : ',logreg_model.score(X_train,y_train) ,'\n')
print('Test Score : ',logreg_model.score(X_test,y_test) ,'\n')
print('Accuracy Score : ',accuracy_score(y_test,y_pred1),'\n')

proba1 = logreg_model.predict_proba(X_test)
proba1





# predict probabilities on Test and take probability for class 1([:1])
y_pred_prob_test = logreg_model.predict_proba(X_test)[:, 1]
#predict labels on test dataset
y_pred_test = logreg_model.predict(X_test)
# create onfusion matrix
cm = confusion_matrix(y_test, y_pred_test)
print(cm," --> confusion Matrix ",'\n')
# ROC- AUC score
print("ROC-AUC score  test dataset:  ", roc_auc_score(y_test,y_pred_prob_test),'\n')
#Precision score
print("precision score  test dataset:  ", precision_score(y_test,y_pred_test),'\n')
#Recall Score
print("Recall score  test dataset:  ", recall_score(y_test,y_pred_test),'\n')
#f1 score
print("f1 score  test dataset :  ", f1_score(y_test,y_pred_test),'\n')
# Out:
# Train Score :  0.8005701437404641
#
# Test Score :  0.7999518198060748
#
# Accuracy Score :  0.7999518198060748
#
# [[  334  9679]
#  [  286 39514]]  --> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7082983478262178
#
# precision score  test dataset:   0.8032443640355336
#
# Recall score  test dataset:   0.9928140703517588
#
# f1 score  test dataset :   0.8880249008348973

# %% [markdown]
# ## Non-outlier model training end.
# ---

# %% [markdown]
# ## Model trained on non-outlier scaled data.
# ---

# %%
from sklearn.preprocessing import StandardScaler

# it will learn mu and sig across all the features
scaler = StandardScaler()
scaler.fit(X_train) 

X_train1 = scaler.transform(X_train)
X_test1 = scaler.transform(X_test)

# %%
len(X_train1),len(y_train.values)
# Out:
# (199248, 199248)

# %%
from sklearn.linear_model import LogisticRegression
scaled_logreg_model = LogisticRegression(C=0.1,max_iter=100)

# %%
scaled_logreg_model.fit(X_train1,y_train.values.reshape(-1,1))
# Out:
# LogisticRegression(C=0.1)

# %%
scaled_logreg_model_coef = scaled_logreg_model.coef_
scaled_logreg_model_inter = scaled_logreg_model.intercept_
y_predscaled = scaled_logreg_model.predict(X_test1)

print('coefficients : ',scaled_logreg_model.coef_,'\n')
print('intercept : ',scaled_logreg_model.intercept_,'\n')
# Out:
# coefficients :  [[ 0.10918485  0.25849837 -0.70285931 -0.19711912 -0.02076846 -0.2577621
#    0.68478548  0.05204214  0.11121383  0.1040638   0.06047554  0.27927191
#   -0.08696177  0.34576299 -0.1526695   0.047328   -0.1325843   0.05420499
#   -0.13295258  0.06189438 -0.06428123  0.00374489  0.03549692  0.18844622]]
#
# intercept :  [1.72710215]

# %%
values = []
x_pos = []
for col in X.columns:
    values.append(col)
    
values1 = np.array(values).reshape(-1,1)
pos1 = scaled_logreg_model_coef[0].reshape(-1,1)
df_mod = pd.DataFrame(np.concatenate((values1,pos1),axis=1),columns=['feature','coef'])
df_mod['coef']=df_mod['coef'].astype(float)

plt.figure(figsize=(13,6))
sns.barplot(data= df_mod,x='feature',y='coef')

plt.xticks(rotation=90)
plt.title(
    'Feature weights for scaled logistic regression model',
    fontsize=18,
    fontname='Comic Sans MS')
plt.grid()
plt.show()

# %% [markdown]
# ### Observation 14
# ---
#
# - Using standard scaled imbalanced data we can observe that employee titles have the best positive weights among all the features.
#
#
# - Interest rates have the best negetive weights among all the features.
#
#
#
# - Grades and subgrades contibutes good negetive weights.
#
#
# - Terms and titles contibutes good positive weights.

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import recall_score,precision_score,roc_auc_score





# predict probabilities on Test and take probability for class 1([:1])
y_pred_prob_test = scaled_logreg_model.predict_proba(X_test1)[:, 1]
#predict labels on test dataset
y_pred_test = scaled_logreg_model.predict(X_test1)
# create onfusion matrix
cm = confusion_matrix(y_test, y_pred_test)
print(cm,"  ---> confusion Matrix  ",'\n')
# ROC- AUC score
print("ROC-AUC score  test dataset:  ", roc_auc_score(y_test,y_pred_prob_test) ,'\n')
#Precision score
print("precision score  test dataset:  ", precision_score(y_test,y_pred_test) ,'\n')
#Recall Score
print("Recall score  test dataset:  ", recall_score(y_test,y_pred_test) ,'\n')
#f1 score
print("f1 score  test dataset :  ", f1_score(y_test,y_pred_test) ,'\n')






print('Train Score : ',scaled_logreg_model.score(X_train1,y_train) ,'\n')
print('Test Score : ',scaled_logreg_model.score(X_test1,y_test) ,'\n')
print('Accuracy Score : ',accuracy_score(y_test,y_predscaled),'\n')

proba1 = scaled_logreg_model.predict_proba(X_test1)
# Out:
# [[ 2235  7778]
#  [ 1329 38471]]   ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7875242335717336
#
# precision score  test dataset:   0.8318233907760167
#
# Recall score  test dataset:   0.966608040201005
#
# f1 score  test dataset :   0.8941649525270484
#
# Train Score :  0.8180307957921786
#
# Test Score :  0.8171762391343625
#
# Accuracy Score :  0.8171762391343625

# %% [markdown]
# ## Non-outlier scaled model end.
# ---

# %% [markdown]
# ## KNN imputed missing values model.
# ---

# %%
X = df_trans.loc[:, df_trans.columns != 'loan_status']
y = df_trans.loan_status

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.impute import KNNImputer

# %%
knn = KNNImputer(n_neighbors=7)

# %%
knn.fit(X_train)
# Out:
# KNNImputer(n_neighbors=7)

# %%
df_trans1 = pd.read_csv('LoanTapKNN_X_train')
df_trans1_xtest = pd.read_csv('LoanTapKNN_X_test')

# %%
Knn_logreg_model = LogisticRegression(C=.01,max_iter=100)
Knn_logreg_model.fit(df_trans1,y_train)
# Out:
# LogisticRegression(C=0.01)

# %%
Knnlogreg_model_intercept = Knn_logreg_model.intercept_
Knnlogreg_model_coef = Knn_logreg_model.coef_
y_pred2 = Knn_logreg_model.predict(df_trans1_xtest)

# %%
plt.figure(figsize=(13,6))
sns.barplot(data=pd.DataFrame(Knnlogreg_model_coef))
plt.show()

# %%
# print('intercept : ',Knnlogreg_model_intercept,'\n')
# print('coefficients : ',Knnlogreg_model_coef,'\n')

# print('KNN_ypred : ',y_pred2)




print('Train Score : ',Knn_logreg_model.score(df_trans1,y_train) ,'\n')
print('Test Score : ',Knn_logreg_model.score(df_trans1_xtest,y_test) ,'\n')






from sklearn.metrics import confusion_matrix 
from sklearn.metrics import recall_score,precision_score,roc_auc_score

# predict probabilities on Test and take probability for class 1([:1])
y_pred_prob_test = Knn_logreg_model.predict_proba(df_trans1_xtest)[:, 1]

#predict labels on test dataset
y_pred_test = Knn_logreg_model.predict(df_trans1_xtest)

# create onfusion matrix
cm = confusion_matrix(y_test, y_pred_test)
print(cm,"---> confusion Matrix ",'\n')

# ROC- AUC score
print("ROC-AUC score  test dataset:  ", roc_auc_score(y_test,y_pred_prob_test),'\n')

#Precision score
print("precision score  test dataset:  ", precision_score(y_test,y_pred_test),'\n')

#Recall Score
print("Recall score  test dataset:  ", recall_score(y_test,y_pred_test),'\n')

#f1 score
print("f1 score  test dataset :  ", f1_score(y_test,y_pred_test),'\n')
# Out:
# Train Score :  0.8039605585435446
#
# Test Score :  0.8035881120117163
#
# [[ 1110 14460]
#  [ 1097 62539]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7035784792061367
#
# precision score  test dataset:   0.8122053533162769
#
# Recall score  test dataset:   0.9827613300647432
#
# f1 score  test dataset :   0.8893803107334589

# %% [markdown]
# ## KNN Ends.
# ---

# %% [markdown]
# ## Trained multiple models with different properties.
# ---

# %%
from sklearn.metrics import roc_auc_score,precision_recall_curve,roc_curve

# %%
scaler = StandardScaler()
scaler.fit(X_train) 

X_train1 = scaler.transform(X_train)
X_test1 = scaler.transform(X_test)

# %%
# Functions to use logistic regression on scaled data. 

def log_reg_scaled(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X,
                                                        y,
                                                        test_size=0.2,
                                                        random_state=1)
    lr = LogisticRegression(penalty='l2',
                            C=0.1,
                            class_weight={'auto'
                            })
    scaler = StandardScaler()
    scaler.fit(X_train) 
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_test)
    prob = lr.predict_proba(X_test)
    cm = confusion_matrix(y_test, y_pred)
    print('Train Score : ', lr.score(X_train, y_train), '\n')
    print('Test Score : ', lr.score(X_test, y_test), '\n')
    print('Accuracy Score : ', accuracy_score(y_test, y_pred), '\n')
    print(cm, "---> confusion Matrix ", '\n')
    print("ROC-AUC score  test dataset:  ", roc_auc_score(y_test, prob[:, 1]),
          '\n')
    print("precision score  test dataset:  ", precision_score(y_test, y_pred),
          '\n')
    print("Recall score  test dataset:  ", recall_score(y_test, y_pred), '\n')
    print("f1 score  test dataset :  ", f1_score(y_test, y_pred), '\n')
    return (prob[:, 1], y_test)





def log_reg_scaled1(X_train, X_test,y_train,y_test):

    lr = LogisticRegression(penalty='l2',
                            C=0.1,
                            class_weight={'auto'
                            })
    scaler = StandardScaler()
    scaler.fit(X_train) 
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_test)
    prob = lr.predict_proba(X_test)
    cm = confusion_matrix(y_test, y_pred)
    print('Train Score : ', lr.score(X_train, y_train), '\n')
    print('Test Score : ', lr.score(X_test, y_test), '\n')
    print('Accuracy Score : ', accuracy_score(y_test, y_pred), '\n')
    print(cm, "---> confusion Matrix ", '\n')
    print("ROC-AUC score  test dataset:  ", roc_auc_score(y_test, prob[:, 1]),
          '\n')
    print("precision score  test dataset:  ", precision_score(y_test, y_pred),
          '\n')
    print("Recall score  test dataset:  ", recall_score(y_test, y_pred), '\n')
    print("f1 score  test dataset :  ", f1_score(y_test, y_pred), '\n')
    return (prob[:, 1])

# %%
# Functions to use logistic regression on normal given data. 



def log_reg(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X,
                                                        y,
                                                        test_size=0.2,
                                                        random_state=1)
    lr = LogisticRegression(penalty='l2',
                            C=0.1,
                            class_weight={'auto'
                            })
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_test)
    prob = lr.predict_proba(X_test)
    cm = confusion_matrix(y_test, y_pred)
    print('Train Score : ', lr.score(X_train, y_train), '\n')
    print('Test Score : ', lr.score(X_test, y_test), '\n')
    print('Accuracy Score : ', accuracy_score(y_test, y_pred), '\n')
    print(cm, "---> confusion Matrix ", '\n')
    print("ROC-AUC score  test dataset:  ", roc_auc_score(y_test, prob[:, 1]),
          '\n')
    print("precision score  test dataset:  ", precision_score(y_test, y_pred),
          '\n')
    print("Recall score  test dataset:  ", recall_score(y_test, y_pred), '\n')
    print("f1 score  test dataset :  ", f1_score(y_test, y_pred), '\n')
    return (prob[:, 1], y_test)





def log_reg1(X_train, X_test,y_train,y_test):

    lr = LogisticRegression(penalty='l2',
                            C=0.1,
                            class_weight={'auto'
                            })
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_test)
    prob = lr.predict_proba(X_test)
    cm = confusion_matrix(y_test, y_pred)
    print('Train Score : ', lr.score(X_train, y_train), '\n')
    print('Test Score : ', lr.score(X_test, y_test), '\n')
    print('Accuracy Score : ', accuracy_score(y_test, y_pred), '\n')
    print(cm, "---> confusion Matrix ", '\n')
    print("ROC-AUC score  test dataset:  ", roc_auc_score(y_test, prob[:, 1]),
          '\n')
    print("precision score  test dataset:  ", precision_score(y_test, y_pred),
          '\n')
    print("Recall score  test dataset:  ", recall_score(y_test, y_pred), '\n')
    print("f1 score  test dataset :  ", f1_score(y_test, y_pred), '\n')
    return (prob[:, 1])

# %%
X2 = df.loc[:,df.columns!='loan_status']
y2 = df.loan_status

# %%
# Functions to plot precision recall and roc-auc curve.

def plot_pre_curve(y_test,probs):
    precision, recall, thresholds = precision_recall_curve(y_test, probs)
    plt.plot([0, 1], [0.5, 0.5], linestyle='--')
    # plot the precision-recall curve for the model
    plt.plot(recall, precision, marker='.')
    plt.title("Precision Recall curve",fontname='Comic Sans MS',fontsize=15)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    # show the plot
    plt.show()
    
def plot_roc(y_test,prob):
    fpr, tpr, thresholds = roc_curve(y_test, probs)
    # plot no skill
    plt.plot([0, 1], [0, 1], linestyle='--')
    # plot the roc curve for the model
    plt.plot(fpr, tpr, marker='.')
    plt.title("ROC curve",fontname='Comic Sans MS',fontsize=15)
    plt.xlabel('false positive rate')
    plt.ylabel('true positive rate')
    # show the plot
    plt.show()

# %%
# Normal Imbalanced Model With No Outlier
print('_' * 60)
print('                Normal Imbalanced Model')
print('_' * 60)

df.loan_status.value_counts().plot(
    kind='bar',
    color=('yellow', 'lightgreen'),
)
plt.title("Target variable(loan_status) imbalance check",
          fontsize=15,
          fontname='Comic Sans MS')

plt.show()
print('_' * 60)
probs, y_test = log_reg(X2, y2)
print('_' * 60)
plot_pre_curve(y_test, probs)
plot_roc(y_test, probs)
# Out:
# ____________________________________________________________
#                 Normal Imbalanced Model
# ____________________________________________________________
# ____________________________________________________________
# Train Score :  0.8002790492250863
#
# Test Score :  0.7993495673820087
#
# Accuracy Score :  0.7993495673820087
#
# [[  735  9331]
#  [  664 39083]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7043382070915049
#
# precision score  test dataset:   0.8072664931631346
#
# Recall score  test dataset:   0.9832943366794978
#
# f1 score  test dataset :   0.8866278740032439
#
# ____________________________________________________________

# %%
# Standard Scaled Imbalanced Model With No Outlier
print('_' * 60)
print('                Normal Imbalanced Model')
print('_' * 60)

df.loan_status.value_counts().plot(
    kind='bar',
    color=('yellow', 'lightgreen'),
)
plt.title("Target variable(loan_status) imbalance check",
          fontsize=15,
          fontname='Comic Sans MS')

plt.show()
print('_' * 60)
probs, y_test = log_reg(X2, y2)
print('_' * 60)
plot_pre_curve(y_test, probs)
plot_roc(y_test, probs)

print('_' * 60)
print('                Scaled Imbalanced Model')
print('_' * 60)

df.loan_status.value_counts().plot(
    kind='bar',
    color=('yellow', 'lightgreen'),
)
plt.title("Target variable(loan_status) imbalance check",
          fontsize=15,
          fontname='Comic Sans MS')

plt.show()
print('_' * 60)
probs, y_test = log_reg_scaled(X2, y2)
print('_' * 60)
plot_pre_curve(y_test, probs)
plot_roc(y_test, probs)
# Out:
# ____________________________________________________________
#                 Normal Imbalanced Model
# ____________________________________________________________
# ____________________________________________________________
# Train Score :  0.8002790492250863
#
# Test Score :  0.7993495673820087
#
# Accuracy Score :  0.7993495673820087
#
# [[  735  9331]
#  [  664 39083]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7043382070915049
#
# precision score  test dataset:   0.8072664931631346
#
# Recall score  test dataset:   0.9832943366794978
#
# f1 score  test dataset :   0.8866278740032439
#
# ____________________________________________________________
# ____________________________________________________________
#                 Scaled Imbalanced Model
# ____________________________________________________________
# ____________________________________________________________
# Train Score :  0.818020758050269
#
# Test Score :  0.8167948125991207
#
# ...

# %% [markdown]
# ***Above metrics ( Scaled Imbalanced Model ) have one of the best overall metrics among all the models***

# %% [markdown]
# ----

# %%
# Undersampling

from sklearn.utils import resample



X_train, X_test, y_train, y_test = train_test_split(df.loc[:,df.columns!='loan_status'],df.loan_status,test_size=0.2,random_state=2)


X=pd.concat([X_train,y_train],axis=1)

default = X[X.loan_status ==0]
paid = X[X.loan_status ==1]

df_downsampled = resample(paid,replace=True,n_samples=len(default),random_state=27)
downsampled = pd.concat([default,df_downsampled])




X_train = downsampled.loc[:,downsampled.columns!='loan_status']
y_train = downsampled.loan_status



print('_' * 60)
print('                    Downsampled Normal Model')
print('_' * 60)

downsampled.loan_status.value_counts().plot(
    kind='bar',
    color=('yellow', 'lightgreen'),
)
plt.title("Target variable(loan_status) imbalance check",
          fontsize=15,
          fontname='Comic Sans MS')

plt.show()
print('_' * 60)
probs= log_reg1(X_train, X_test, y_train, y_test)
print('_' * 60)
plot_pre_curve(y_test, probs)
plot_roc(y_test, probs)
# Out:
# ____________________________________________________________
#                     Downsampled Normal Model
# ____________________________________________________________
# ____________________________________________________________
# Train Score :  0.6438762484042952
#
# Test Score :  0.6709092004095316
#
# Accuracy Score :  0.6709092004095316
#
# [[ 6080  3933]
#  [12460 27340]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7050651163537651
#
# precision score  test dataset:   0.8742365618904486
#
# Recall score  test dataset:   0.6869346733668342
#
# f1 score  test dataset :   0.7693498234209897
#
# ____________________________________________________________

# %%
# Undersampling

from sklearn.utils import resample



X_train, X_test, y_train, y_test = train_test_split(df.loc[:,df.columns!='loan_status'],df.loan_status,test_size=0.2,random_state=2)


X=pd.concat([X_train,y_train],axis=1)

default = X[X.loan_status ==0]
paid = X[X.loan_status ==1]

df_downsampled = resample(paid,replace=True,n_samples=len(default),random_state=27)
downsampled = pd.concat([default,df_downsampled])




X_train = downsampled.loc[:,downsampled.columns!='loan_status']
y_train = downsampled.loan_status



print('_' * 60)
print('                    Downsampled Scaled Model')
print('_' * 60)

downsampled.loan_status.value_counts().plot(
    kind='bar',
    color=('yellow', 'lightgreen'),
)
plt.title("Target variable(loan_status) imbalance check",
          fontsize=15,
          fontname='Comic Sans MS')

plt.show()
print('_' * 60)
probs= log_reg_scaled1(X_train, X_test, y_train, y_test)
print('_' * 60)
plot_pre_curve(y_test, probs)
plot_roc(y_test, probs)
# Out:
# ____________________________________________________________
#                     Downsampled Scaled Model
# ____________________________________________________________
# ____________________________________________________________
# Train Score :  0.7079422292308077
#
# Test Score :  0.7123843173468773
#
# Accuracy Score :  0.7123843173468773
#
# [[ 7053  2960]
#  [11367 28433]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7879791999044458
#
# precision score  test dataset:   0.9057114643391839
#
# Recall score  test dataset:   0.7143969849246231
#
# f1 score  test dataset :   0.7987583048895256
#
# ____________________________________________________________

# %% [markdown]
# ***Above metrics ( Downsampled Scaled Model ) have the best precision metrics among all the models.***

# %%
# Oversampling

from sklearn.utils import resample



X_train, X_test, y_train, y_test = train_test_split(df.loc[:,df.columns!='loan_status'],df.loan_status,test_size=0.2,random_state=2)


X=pd.concat([X_train,y_train],axis=1)
default = X[X.loan_status ==0]
paid = X[X.loan_status ==1]

df_upsampled = resample(default,replace=True,n_samples=len(paid),random_state=27)
upsampled = pd.concat([paid,df_upsampled])





X_train = upsampled.loc[:,upsampled.columns!='loan_status']
y_train = upsampled.loan_status



print('_' * 60)
print('                    Upsampled Normal Model')
print('_' * 60)

upsampled.loan_status.value_counts().plot(
    kind='bar',
    color=('yellow', 'lightgreen'),
)
plt.title("Target variable(loan_status) imbalance check",
          fontsize=15,
          fontname='Comic Sans MS')

plt.show()
print('_' * 60)
probs= log_reg1(X_train, X_test, y_train, y_test)
print('_' * 60)
plot_pre_curve(y_test, probs)
plot_roc(y_test, probs)
# Out:
# ____________________________________________________________
#                     Upsampled Normal Model
# ____________________________________________________________
# ____________________________________________________________
# Train Score :  0.6460542257544084
#
# Test Score :  0.6605303836347941
#
# Accuracy Score :  0.6605303836347941
#
# [[ 6315  3698]
#  [13212 26588]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7068814184775871
#
# precision score  test dataset:   0.8778973783266195
#
# Recall score  test dataset:   0.6680402010050251
#
# f1 score  test dataset :   0.7587249950061352
#
# ____________________________________________________________

# %%
# Oversampling

from sklearn.utils import resample



X_train, X_test, y_train, y_test = train_test_split(df.loc[:,df.columns!='loan_status'],df.loan_status,test_size=0.2,random_state=2)


X=pd.concat([X_train,y_train],axis=1)
default = X[X.loan_status ==0]
paid = X[X.loan_status ==1]

df_upsampled = resample(default,replace=True,n_samples=len(paid),random_state=27)
upsampled = pd.concat([paid,df_upsampled])





X_train = upsampled.loc[:,upsampled.columns!='loan_status']
y_train = upsampled.loan_status



print('_' * 60)
print('                    Upsampled Scaled Model')
print('_' * 60)

upsampled.loan_status.value_counts().plot(
    kind='bar',
    color=('yellow', 'lightgreen'),
)
plt.title("Target variable(loan_status) imbalance check",
          fontsize=15,
          fontname='Comic Sans MS')

plt.show()
print('_' * 60)
probs= log_reg_scaled1(X_train, X_test, y_train, y_test)
print('_' * 60)
plot_pre_curve(y_test, probs)
plot_roc(y_test, probs)
# Out:
# ____________________________________________________________
#                     Upsampled Scaled Model
# ____________________________________________________________
# ____________________________________________________________
# Train Score :  0.7074332849959509
#
# Test Score :  0.7118021400036135
#
# Accuracy Score :  0.7118021400036135
#
# [[ 7069  2944]
#  [11412 28388]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7878953340556774
#
# precision score  test dataset:   0.9060385548321205
#
# Recall score  test dataset:   0.7132663316582915
#
# f1 score  test dataset :   0.7981780352021594
#
# ____________________________________________________________

# %% [markdown]
# ---

# %%
y3
X3.head()
# Out:
#    loan_amnt      term  int_rate  installment  grade  sub_grade  emp_title  \
# 0    10000.0  0.842254     11.44       329.48    5.0       26.0   0.752809
# 1     8000.0  0.842254     11.99       265.68    5.0       25.0   0.683022
# 2    15600.0  0.842254     10.49       506.97    5.0       27.0   0.818181
# 3     7200.0  0.842254      6.49       220.65    6.0       33.0   0.803871
# 4    24375.0  0.680585     17.27       609.33    4.0       20.0   0.803871
#
#    emp_length  home_ownership  annual_inc  ...  revol_util  total_acc  \
# 0    0.815814        0.773378    117000.0  ...        41.8       25.0
# 1    0.807615        0.830439     65000.0  ...        53.3       27.0
# 2    0.793128        0.773378     43057.0  ...        92.2       26.0
# 3    0.810806        0.773378     54000.0  ...        21.5       13.0
# 4    0.799530        0.830439     55000.0  ...        69.8       43.0
#
#    initial_list_status  application_type  mort_acc   address  ultimate_grade  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X3,y3,test_size=0.2,random_state=2)


X_train = np.log(X_train)
X_test = np.log(X_test)




X_train = X_train.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)
X_test = X_test.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)






print('_' * 60)
print('                    Log Transformed Model')
print('_' * 60)

df_trans.loan_status.value_counts().plot(
    kind='bar',
    color=('yellow', 'lightgreen'),
)
plt.title("Target variable(loan_status) imbalance check",
          fontsize=15,
          fontname='Comic Sans MS')

plt.show()
print('_' * 60)
probs= log_reg1(X_train, X_test, y_train, y_test)
print('_' * 60)
plot_pre_curve(y_test, probs)
plot_roc(y_test, probs)
# Out:
# ____________________________________________________________
#                     Log Transformed Model
# ____________________________________________________________
# ____________________________________________________________
# Train Score :  0.8187605736939121
#
# Test Score :  0.8168573087897382
#
# Accuracy Score :  0.8168573087897382
#
# [[ 2652 12918]
#  [ 1588 62048]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.77652494035905
#
# precision score  test dataset:   0.8276818824533788
#
# Recall score  test dataset:   0.9750455716889811
#
# f1 score  test dataset :   0.8953406155755328
#
# ____________________________________________________________

# %% [markdown]
# ***Above metrics ( Log Transformed Model ) have the one of the  best overall metrics among all the models.***

# %% [markdown]
# ## Dimensionallity reduction techniques.
# ---

# %%
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib.patches as mpatches

# %%
X4_pca = scaler.fit_transform(X3)


X_reduced_svd = TruncatedSVD(n_components=28, algorithm='randomized', random_state=42).fit_transform(X4_pca)
X_reduced_pca = PCA(n_components=2, random_state=42).fit_transform(X4_pca)

print('_'*60)
print('Dimensionality reduction by TruncatedSVD')
print('_'*60)
d = log_reg(X_reduced_svd,y3)
print('_'*60)
print('Dimensionality reduction by PCA')
print('_'*60)
d1 = log_reg(X4_pca,y3)


f, (ax3,ax2) = plt.subplots(1,2, figsize=(24,6))
f.suptitle('Clusters using Dimensionality Reduction(Imbalanced Model)', fontsize=22)


blue_patch = mpatches.Patch(color='#0A0AFF', label='Paid')
red_patch = mpatches.Patch(color='#AF0000', label='Not Paid')
# TruncatedSVD scatter plot
ax3.scatter(X_reduced_svd[:,0], X_reduced_svd[:,1], c=(y3 == 0), cmap='coolwarm', label='No Fraud', linewidths=2)
ax3.scatter(X_reduced_svd[:,0], X_reduced_svd[:,1], c=(y3 == 1), cmap='coolwarm', label='Fraud', linewidths=2)
ax3.set_title('Truncated SVD', fontsize=14)

ax3.grid(True)

ax3.legend(handles=[blue_patch, red_patch])
# PCA scatter plot
ax2.scatter(X_reduced_pca[:,0], X_reduced_pca[:,1], c=(y3 == 0), cmap='coolwarm', label='No Fraud', linewidths=2)
ax2.scatter(X_reduced_pca[:,0], X_reduced_pca[:,1], c=(y3 == 1), cmap='coolwarm', label='Fraud', linewidths=2)
ax2.set_title('PCA', fontsize=14)

ax2.grid(True)

ax2.legend(handles=[blue_patch, red_patch])
plt.show()
# Out:
# ____________________________________________________________
# Dimensionality reduction by TruncatedSVD
# ____________________________________________________________
# Train Score :  0.8214907961518066
#
# Test Score :  0.820935282680605
#
# Accuracy Score :  0.820935282680605
#
# [[ 3418 12232]
#  [ 1951 61605]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7853859040463824
#
# precision score  test dataset:   0.8343377981228923
#
# Recall score  test dataset:   0.9693026622191453
#
# f1 score  test dataset :   0.8967705778314762
#
# ____________________________________________________________
# Dimensionality reduction by PCA
# ____________________________________________________________
# Train Score :  0.8215697043153296
#
# Test Score :  0.8209100320682776
#
# Accuracy Score :  0.8209100320682776
#
# [[ 3449 12201]
#  [ 1984 61572]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.786297251479262
#
# precision score  test dataset:   0.8346142897808141
#
# ...

# %% [markdown]
# ***Above metrics ( Dimensionality Reduced Models ) have the best overall metrics among all the models.***

# %%
# PCA and TruncatedSVD on oversampled data.

up_X = upsampled.loc[:,upsampled.columns!='loan_status']
up_y = upsampled.loan_status


X4_pca = scaler.fit_transform(up_X)


X_reduced_svd = TruncatedSVD(n_components=2, algorithm='randomized', random_state=42).fit_transform(X4_pca)
X_reduced_pca = PCA(n_components=2, random_state=42).fit_transform(X4_pca)

print('_'*60)
print('Dimensionality reduction by TruncatedSVD(Overrsampled Model)')
print('_'*60)
d = log_reg(X_reduced_svd,up_y)
print('_'*60)
print('Dimensionality reduction by PCA(Ovrsampled Model)')
print('_'*60)
d1 = log_reg(X4_pca,up_y)

print('_'*120)
print('_'*120)
f, (ax3,ax2) = plt.subplots(1,2, figsize=(24,6))
# labels = ['No Fraud', 'Fraud']
f.suptitle('Clusters using Dimensionality Reduction(Overrsampled Model)', fontsize=22)


blue_patch = mpatches.Patch(color='#0A0AFF', label='Paid')
red_patch = mpatches.Patch(color='#AF0000', label='Not Paid')
# TruncatedSVD scatter plot
ax3.scatter(X_reduced_svd[:,0], X_reduced_svd[:,1], c=(up_y == 0), cmap='coolwarm', linewidths=2)
ax3.scatter(X_reduced_svd[:,0], X_reduced_svd[:,1], c=(up_y == 1), cmap='coolwarm', linewidths=2)
ax3.set_title('Truncated SVD', fontsize=14)

ax3.grid(True)

ax3.legend(handles=[blue_patch, red_patch])
# PCA scatter plot
ax2.scatter(X_reduced_pca[:,0], X_reduced_pca[:,1], c=(up_y == 0), cmap='coolwarm', linewidths=2)
ax2.scatter(X_reduced_pca[:,0], X_reduced_pca[:,1], c=(up_y == 1), cmap='coolwarm', linewidths=2)
ax2.set_title('PCA', fontsize=14)

ax2.grid(True)

ax2.legend(handles=[blue_patch, red_patch])
plt.show()
# Out:
# ____________________________________________________________
# Dimensionality reduction by TruncatedSVD(Overrsampled Model)
# ____________________________________________________________
# Train Score :  0.6572280529671407
#
# Test Score :  0.6553461290980712
#
# Accuracy Score :  0.6553461290980712
#
# [[20556 11264]
#  [10697 21202]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7097264042982615
#
# precision score  test dataset:   0.6530524240744163
#
# Recall score  test dataset:   0.6646603341797549
#
# f1 score  test dataset :   0.6588052513011731
#
# ____________________________________________________________
# Dimensionality reduction by PCA(Ovrsampled Model)
# ____________________________________________________________
# Train Score :  0.7083354585581167
#
# Test Score :  0.7053155259812615
#
# Accuracy Score :  0.7053155259812615
#
# [[22301  9519]
#  [ 9258 22641]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.781047627756754
#
# ...

# %%
# PCA and TruncatedSVD on undersampled data.


down_X = downsampled.loc[:,downsampled.columns!='loan_status']
down_y = downsampled.loan_status


X4_pca = scaler.fit_transform(down_X)


X_reduced_svd = TruncatedSVD(n_components=2, algorithm='randomized', random_state=42).fit_transform(X4_pca)
X_reduced_pca = PCA(n_components=2, random_state=42).fit_transform(X4_pca)

print('_'*60)
print('Dimensionality reduction by TruncatedSVD(Undersampled Model)')
print('_'*60)
d = log_reg(X_reduced_svd,down_y)
print('_'*60)
print('Dimensionality reduction by PCA(Undersampled Model)')
print('_'*60)
d1 = log_reg(X4_pca,down_y)
print('_'*120)
print('_'*120)



f, (ax3,ax2) = plt.subplots(1,2, figsize=(24,6))
# labels = ['No Fraud', 'Fraud']
f.suptitle('Clusters using Dimensionality Reduction (Undersampled Model)', fontsize=24)


blue_patch = mpatches.Patch(color='#0A0AFF', label='Paid')
red_patch = mpatches.Patch(color='#AF0000', label='Not Paid')
# TruncatedSVD scatter plot
ax3.scatter(X_reduced_svd[:,0], X_reduced_svd[:,1], c=(down_y == 0), cmap='coolwarm', linewidths=2)
ax3.scatter(X_reduced_svd[:,0], X_reduced_svd[:,1], c=(down_y == 1), cmap='coolwarm', linewidths=2)
ax3.set_title('Truncated SVD', fontsize=14)

ax3.grid(True)

ax3.legend(handles=[blue_patch, red_patch])
# PCA scatter plot
ax2.scatter(X_reduced_pca[:,0], X_reduced_pca[:,1], c=(down_y == 0), cmap='coolwarm', linewidths=2)
ax2.scatter(X_reduced_pca[:,0], X_reduced_pca[:,1], c=(down_y == 1), cmap='coolwarm', linewidths=2)
ax2.set_title('PCA', fontsize=14)

ax2.grid(True)

ax2.legend(handles=[blue_patch, red_patch])
plt.show()
# Out:
# ____________________________________________________________
# Dimensionality reduction by TruncatedSVD(Undersampled Model)
# ____________________________________________________________
# Train Score :  0.6582343830665979
#
# Test Score :  0.6545898254176835
#
# Accuracy Score :  0.6545898254176835
#
# [[5166 2820]
#  [2700 5295]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7124757569022837
#
# precision score  test dataset:   0.6524953789279113
#
# Recall score  test dataset:   0.6622889305816135
#
# f1 score  test dataset :   0.6573556797020484
#
# ____________________________________________________________
# Dimensionality reduction by PCA(Undersampled Model)
# ____________________________________________________________
# Train Score :  0.7068881901096666
#
# Test Score :  0.7096552155684875
#
# Accuracy Score :  0.7096552155684875
#
# [[5626 2360]
#  [2280 5715]] ---> confusion Matrix
#
# ROC-AUC score  test dataset:   0.7837737930058027
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Insights
# ---
#
#
# **Observation 1**
#
#
# - There are very least low grade loans.
#
#
# - There are very least low subgrade loans.
#
#
# - Most loan amounts are above 15000.
#
#
# - Most of the interest rates are between 8 - 18.
#
#
# - Most of the installments are between 200 - 500.
#
#
# **Observation 2**
#
#
# - 80% of fully paid loans are on 36 months terms.
#
#
# - 60% of charged off loans are on 36 months term.
#
#
# - When loan terms exceded to 60 months probability of charged off gets increased.
#
#
# **Observation 3**
#
# - Probability of fully paid grade A loans are above 90%.
#
#
# - As grade increases probability of fully paid loans get decreases.
#
#
# - Probability of paying grade G loan is least with nearly 57% approx.
#
#
# **Observation 4**
#
#
# - As subgrade increases probability of fully paid loans get decreases.
#
#
#
# - The least quality loan is of G5 grade with paying probability of approx 50%.
#
#
# - The highest quality loan is of A1 grade with paying probability of above 90%.
#
#
# **Observation 5**
#
#
# - According to employment length above or equal to 1 year, probability of paying loans are more than making defaults.
#
#
#
# **Observation 6**
#
#
# - Probability of paying loans according to home ownership is nearly 80%.
#
#
#
# **Observation 7**
#
#
# - Probability of paying loans is the highest with above 80% when not verified.
#
#
#
# **Observation 8**
#
#
# - Loans that are taken for cars and weddings have the highest probability of paying back.
#
#
#
# - Loans that are taken for small businesses have the least probability of paying back.
#
#
#
# **Observation 9**
#
#
#
# - Loans that have 12,19,40,86 numbers of derogatory records are 100% likely to make a default.
#
#
# - Loans that have 15,17,24 numbers of derogatory records are 100% probability of paying back the loans.
#
#
#
# **Observation 8**
#
#
# - Probability of fully paid loans are more according to initial list status.
#
#
#
# **Observation 9**
#
#
# - Joint loans are most likely to get fully paid with probability of above 80%.
#
#
# - Individual loans have 80% probability of paying back.
#
#
# - Direct paying loans have least probability of paying back with nearly 38%.
#
#
#
# **Observation 10**
#
#
# - Loans that have 8 numbers of public records bankruptcies have least probabillity of paying back with 50%.
#
#
# - Loans that have 5 numbers of public records bankruptcies have highest probabillity of paying back with nearly 83%.
#
#
#
# **Observation 11**
#
#
# - The range of most of the features got reduced multiple folds after removal of outliers
#
#
# **Observation 12**
#
#
# - Loan Status is our target variable.
#
#
# - Target variable has highest positive correlation with ultimate grade which is an engineered feature which signifies the better the grade the better the chances of paying back loans.
#
#
# - Target variable has highest negetive correlation with interest rate which signifies chance of not paying loans as interest rates increases.
#
#
# - Target variable has good positive correlation with employee title.
#
#
# - Target variable has good positive correlation with both grades and subgrades, which signifies the more the grade the better chance of paying loan back.
#
#
#
# **observation 13**
#
#
# - Using simple imbalanced data model training we can observe that subgrade has best weights among all the features.
#
#
#
#
# **Observation 14**
#
#
# - Using standard scaled imbalanced data we can observe that employee titles have the best positive weights among all the features.
#
#
# - Interest rates have the best negetive weights among all the features.
#
#
# - Grades and subgrades contibutes good negetive weights.
#
#
#
# - Terms and titles contibutes good positive weights.

# %% [markdown]
# # Recommendations
# ---
#
# - Loantap should focus on betterment of low grade loans as probability of paying back **G grade loans** are approx  **55 %**, one out of two loans are going to get charged off.
#
#
#
# - Loantap should speially keep track on the loans that has **high interest paying loans** as there are **40% chance** to make a **default**. Also loantap should **promote low interest** loans as much as possible as proability of **paying back** the loans are **abobe 90%**.
#
#
#
#
#
#
# - Loantap should **promote joint loans** as much as possible as it has the **highest probability** of getting fully paid among all catagories.
#
#
#
#
#
# - As there are **high numbers of public derogatory records** the chances of **making default increases**, thus loantap should avoid paying loans to such users.
