# %% [markdown]
# # Aerofit Data Analysis
# - Submitted by Bishal Roy.
#
# - Feel free to provide feedback personaly if required regarding any improvements.

# %% [markdown]
# # Business Problem
#
# The market research team at AeroFit wants to identify the characteristics of the target audience for each type of treadmill offered by the company, to provide a better recommendation of the treadmills to the new customers. The team decides to investigate whether there are differences across the product with respect to customer characteristics.
#
# Perform descriptive analytics to create a customer profile for each AeroFit treadmill product by developing appropriate tables and charts.
#
#
# For each AeroFit treadmill product, construct two-way contingency tables and compute all conditional and marginal probabilities along with their insights/impact on the business.

# %% [markdown]
# # Recommendations
# 1)  Users with age group 20 - 40 has most probability to buy Aerofit's product. ---(Reference : cell 2)
#
#
# 2)  Users with fitness level 3 have nearly 69 % probability to buy  product KP481 and KP421. ---(Reference : cell 3)
#
#
# 3) Users that use product more then 4 times are most likely to use KP718. ---(Reference : cell 4)
#
#
# 4) Users that use product less then 5 times are most likely to use KP218 and KP481. ---(Reference : cell 4)
#
#
# 5)  Users with education level 16 have 50% probability of buying  KP281 and KP481. ---(Reference : cell 5)
#
#
# 6)  Users with education level 18 have 50% probability of buying  KP781. ---(Reference : cell 5)
#
#
# 7)  High income users mostly above 50000 income holders buy KP781.---(Reference : cell 7) 8) All the average income users depends on product KP281 and KP281. ---(Reference : cell 7)

# %% [markdown]
# # 1) Pieplot representing total quantity of product.

# %%
# #cell 1
explode = (0.1, 0, 0)  
fig1, ax1 = plt.subplots()
ax1.pie(product_val, explode=explode, labels=product_name, autopct='%1.1f%%',shadow=True, startangle=90,radius=2.1)
''' Equal aspect ratio ensures that pie is drawn as a circle'''
ax1.axis('tight')  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Observation from pieplot.
#
# 1) Aerofit should mostly target age-group of 20-30 years.
#
# 2) Aerofit should mostly target Females of age-group of 20-30 years for product KP781, as most of the buyers are male.
#
# 3) Aerofit should target both male and female of age-group of 20-30 for products KP481 and KP281.

# %% [markdown]
# # 2)  Barplot representing the separated age group of users of different products for both male and female.

# %%
#cell 2
plt.subplot(1,3,1)
sns.barplot(data=KP481_df,x='Age Groups',y='Prob Buying KP481',hue='Gender',palette='YlOrRd')
plt.title('Gender-wise Probability % for KP481')
plt.xticks(rotation=45)

plt.subplot(1,3,2)
sns.barplot(data=KP281_df,x='Age Groups',y='Prob Buying KP281',hue='Gender',palette='YlOrRd')
plt.title('Gender-wise Probability % for KP281')
plt.xticks(rotation=45)

plt.subplot(1,3,3)
sns.barplot(data=KP781_df,x='Age Groups',y='Prob Buying KP781',hue='Gender',palette='YlOrRd')
plt.title('Gender-wise Probability % for KP781')
plt.xticks(rotation=45)

plt.subplots_adjust(left=1,bottom=.1,right=3,top=1, wspace=0.5, hspace=0.5)

plt.show()

# %% [markdown]
# # Observation from Barplot.
#
#
# 1) Aerofit should mostly target age-group of 20-40 years old users of both male and female for product KP481, as the probability of using KP481 is much high for 20-40 age catagory then other.
#
# 2) Aerofit should mostly target age-group of 20-30 years old users of both male and female for product KP281, as the probability of using KP281 is much high for 20-30 age catagory then other. Aerofit should also focus on increasing user base for 30-40 age group as they also have little probability of using the product.
#
# 3) Aerofit should mostly target age-group of 20-30 years old male users for product KP781, as the probability of using KP781 is much high for 20-30 age catagory then other.

# %% [markdown]
# # 3) Conditional probability of product given fitness level ie P( product | fitness level ).

# %%
#cell 3
cond_Prob = Joint_vals_fitness.divide(product,axis=1)
cond_Prob.plot.bar(figsize=(15,6),grid=True,color={"black","m","grey"})
plt.title('Every probability in this table represents a conditional probability of product given fitness level ie P( Product | Fitness Level ).')
plt.show()

# %% [markdown]
# # Observations from conditional probability of ( Product | Fitness Level ).
# key Notes.
#
# 1) Probability of using KP281 is much higher by level 3 users then others. Aerofit should focus on retaining level 3 users and should focus on increasing level2 and level4 users as they aslo use KP281.
#
# 2) Probability of using KP481 is much higher by level 3 users then others. Aerofit should focus on retaining level 3 users and should focus on increasing level2 and level4 users as they aslo use KP281.
#
# 3) Probability of using KP781 is much higher by level 5 users then others. Aerofit should focus on retaining level 5 users and should focus on increasing level3 and level4 users as they aslo use KP281.

# %% [markdown]
# # 4) Conditional probability of product given Usage ie P( product | Usage ).

# %%
#cell 4
def cond_prob(a):
    Joint_vals_fitness = pd.crosstab(df['Usage'],df['Product'],normalize=True)
    product = Joint_vals_fitness.sum(axis=0)
    cond_Prob = Joint_vals_fitness.divide(product,axis=1)
    cond_Prob.plot.bar(figsize=(15,6),grid=True,color={"black","m","grey"})
    plt.title('Every probability in this table represents a conditional probability of product given Usage ie P( Product | Usage ).')
    k = plt.show()
    return k

cond_prob(a)

# %% [markdown]
# # Observations from conditional probability of ( Product | Usage ).

# %% [markdown]
# 1) Users that use product more then 4 times are most likely to use KP718.
#
#
# 2) Users that use product less then 5 times are most likely to use KP218 and KP481.

# %% [markdown]
# # 4) Conditional probability of product given Education ie P( product | Education).

# %%
#cell 5
def cond_prob(a):
    Joint_vals_fitness = pd.crosstab(df['Education'],df['Product'],normalize=True)
    product = Joint_vals_fitness.sum(axis=0)
    cond_Prob = Joint_vals_fitness.divide(product,axis=1)
    cond_Prob.plot.bar(figsize=(15,6),grid=True,color={"black","m","grey"})
    plt.title('Every probability in this table represents a conditional probability of product given Education ie P( Product | Education ).')
    k = plt.show()
    return k


cond_prob(a)

# %% [markdown]
# # Observations from conditional probability of ( Product | Education ).

# %% [markdown]
# 1) Education level 16 uses mostly Aerofits products.
#
# 2) Nearly both 50% of KP281 and KP481 are used by education level 16 users.
#
#
# 3) Nearly both 50% of KP781 are used by education level 18 users.

# %% [markdown]
# # 4) Heatmap representing all the correlation between all the quantitative values.

# %%
# #cell 6
plt.figure(figsize=(15,6))
sns.heatmap(corr,annot=True,cmap='Blues_r')
plt.title('Correlation between diffrent quantitative values.')

plt.yticks(rotation=0)

plt.show()

# %% [markdown]
# # Observation from heatmap
# Key Notes.
#
# 1) Usage got lowered by growing age.
#
# 2) Usage got higher by fitness.
#
# 3) Fitness got higher by miles.
#
#
# 4) Age got increased by fitness.

# %% [markdown]
# # 5) Boxplot representing median, IQR, range, seperated by every product.

# %%
# #cell 7
plt.figure(figsize=(15,6))
plt.title('Income-wise Products Median, IQR')
sns.boxplot(x='Product',y='Income',data=zz,palette='hsv')
plt.show()

# %% [markdown]
# # Observation from above boxplot.
#
# 1) High income users mostly above 50000 income holders buy KP781.
#
# 2) Average income holders mostly depends on KP481 and KP281.

# %% [markdown]
# # 6) Pairplot representing  correlation between all the nuerical values in detailed manner.

# %%
# #cell 8
sns.pairplot(df,hue='Product',palette='YlOrRd',markers=["o", "s", "D"],height=2)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Observations from pairplot:
# key note:
#
# 1) All the high income users with increasing miles depend on KP781 product and avg income users depends on product KP281 and KP281.
#
# 2) Fitness level 3 people who falls between age 20-40 mostly use KP481 and KP281.
#
# 3) By seeing at usage, users that use 3 times a week are the highest and they mostly use KP481 and KP281.
#
# 4) People who runs above 150 miles mostly uses KP781.

# %% [markdown]
# # 7) Boxplot representing the median,IQR,range of income for both single and partnered.

# %%
# #cell 9
plt.figure(figsize=(15,6))
plt.title('MaritalStatus wise Income')
pp = p[['Income','MaritalStatus']]
sns.boxplot(x='MaritalStatus',y='Income',data=pp,palette='hsv')
plt.show()

# %% [markdown]
# # Observation from above boxplot ie Marital wise income.
# 1) Partnerd users have the higher leel of income
#
# 2) Single users have lower average income. Some outliers are present in the single users, who earns nearly 2x in comparison with average earners.

# %% [markdown]
# # Normal Distribution of cleaned sample of Income, Miles and Age columns.

# %%
#cell 10
plt.plot(x,y)
plt.title('Cleaned Normal Distribution for Income')
plt.show()

plt.plot(sorted_rt,followup_rt1)
plt.title('Cleaned Normal Distribution for Miles')
plt.show()

plt.plot(age1,age2)
plt.title('Cleaned Normal Distribution for Age')
plt.show()

# %% [markdown]
# # Observations from Normal Distributions of Income, Miles, Age.

# %% [markdown]
# 1) Most users of Aerofits lies in 50000 income range.
#
# 2) Most users of Aerofits mostly runs from 80-100 miles on average.
#
# 3) Most users of Aerofits falls in nearly age 30.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ....................................................................................................................................................................................................................................................................................................................................................................................................

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # ( * * * * * )Important Code snippets with mentioned cell numbers.
#
# 1) Function for removing all outliers for cleaned sample of Normal Distribution.  -> cell 99
#
#
# 2) Function for finding conditional probability. -> cell 4,5
#
#
# 3) Calculation and explanation of Conditional Probability.     -> cell 77
#
#
# 4) Calculation and explanation of Marginal Probability.  -> cell 78 - cell 80.
#
#
# 5) Probaility of both female and male given buying KP281, KP481, KP781. -> cell 33 - cell 38.
#
#
# 6) Creation of seperated age group according to age present in the dataset.  -> cell 42 - cell 43.
#
#
#
# 7) Calculation of  correlation between all the numerical values.  -> cell 41
#
#
#
# 8) Calculation of Specific Product Probability by specific age group of both male and female starts here. -> cell 53 - cell 64.
#
#
# 9) Representation of all value counts. -> cell 11 - cell 20.
#
#
# 10) All the modules that are used during the completion of project. -> cell 8.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# .............................................................................................................................................................................................................................................................................................................................................................................................

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #  All the codes for above plots and all calculations are done below.( Junks )

# %%
#cell 11
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns
import re
import scipy as scipy
from scipy import stats
from scipy.stats import norm

# %%
#cell 12
df = pd.read_csv('aerofit_treadmill.csv')
df_m = pd.read_csv('aerofit_treadmill.csv')

# %%
#cell 13
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
#cell 14

df['Product'].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
#cell 15
df['Miles'].value_counts()
# Out:
# 85     27
# 95     12
# 66     10
# 75     10
# 47      9
# 106     9
# 94      8
# 113     8
# 100     7
# 53      7
# 64      6
# 56      6
# 200     6
# 180     6
# 127     5
# 160     5
# 150     4
# 42      4
# 120     3
# 103     3
# 170     3
# 74      3
# 38      3
# 132     2
# 141     2
# 169     1
# 188     1
# 212     1
# 260     1
# 140     1
# 112     1
# 360     1
# 21      1
# 80      1
# 300     1
# 280     1
# 240     1
# Name: Miles, dtype: int64

# %%
#cell 16
df['Income'].value_counts()
# Out:
# 45480     14
# 52302      9
# 54576      8
# 53439      8
# 46617      8
#           ..
# 103336     1
# 69721      1
# 75946      1
# 85906      1
# 54781      1
# Name: Income, Length: 62, dtype: int64

# %%
#cell 17
df['Fitness'].value_counts()
# Out:
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: Fitness, dtype: int64

# %%
#cell 18
df['Usage'].sort_values(ascending=False)
# Out:
# 166    7
# 163    7
# 154    6
# 155    6
# 175    6
#       ..
# 43     2
# 132    2
# 138    2
# 139    2
# 121    2
# Name: Usage, Length: 180, dtype: int64

# %%
#cell 19
df['MaritalStatus'].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
#cell 20
df['Education'].value_counts()
# Out:
# 16    85
# 14    55
# 18    23
# 13     5
# 15     5
# 12     3
# 21     3
# 20     1
# Name: Education, dtype: int64

# %%
#cell 21
df['Gender'].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
#cell 22
df['Age'].value_counts()
# Out:
# 25    25
# 23    18
# 24    12
# 26    12
# 28     9
# 35     8
# 33     8
# 30     7
# 38     7
# 21     7
# 22     7
# 27     7
# 31     6
# 34     6
# 29     6
# 20     5
# 40     5
# 32     4
# 19     4
# 48     2
# 37     2
# 47     2
# 45     2
# 44     1
# 46     1
# 18     1
# 43     1
# 42     1
# 41     1
# 39     1
# 36     1
# 50     1
# Name: Age, dtype: int64

# %%
#cell 23
df['Product'].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
#cell 24
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
#cell 25
df.select_dtypes('object').columns
# Out:
# Index(['Product', 'Gender', 'MaritalStatus'], dtype='object')

# %%
#cell 26
df.select_dtypes('number').columns
# Out:
# Index(['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles'], dtype='object')

# %%
#cell 27
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
#cell 28
df.isnull().mean()*100
# Out:
# Product          0.0
# Age              0.0
# Gender           0.0
# Education        0.0
# MaritalStatus    0.0
# Usage            0.0
# Fitness          0.0
# Income           0.0
# Miles            0.0
# dtype: float64

# %%
#cell 29
df['Product'].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
#cell 30
df.groupby('Product')['Usage'].size()
# Out:
# Product
# KP281    80
# KP481    60
# KP781    40
# Name: Usage, dtype: int64

# %%
#cell 31
df['Product'].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
#cell 32
df[df['Product']=='KP281']
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0    KP281   18    Male         14        Single      3        4   29562
# 1    KP281   19    Male         15        Single      2        3   31836
# 2    KP281   19  Female         14     Partnered      4        3   30699
# 3    KP281   19    Male         12        Single      3        3   32973
# 4    KP281   20    Male         13     Partnered      4        2   35247
# ..     ...  ...     ...        ...           ...    ...      ...     ...
# 75   KP281   43    Male         16     Partnered      3        3   53439
# 76   KP281   44  Female         16        Single      3        4   57987
# 77   KP281   46  Female         16     Partnered      3        2   60261
# 78   KP281   47    Male         16     Partnered      4        3   56850
# 79   KP281   50  Female         16     Partnered      3        3   64809
#
#     Miles
# 0     112
# 1      75
# 2      66
# 3      85
# 4      47
# ..    ...
# ...

# %%
#cell 33
m1 = df.filter(['Product','Usage'])
m1.head()
# Out:
#   Product  Usage
# 0   KP281      3
# 1   KP281      2
# 2   KP281      4
# 3   KP281      3
# 4   KP281      4

# %%
#cell 34
# m1.groupby('Product')['Usage'].sum().plot(kind='bar',figsize=(7,4),ylabel='Usage')
# plt.xticks(rotation=45)
# plt.show()

# %%
#cell 35
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# # Probaility of both female and male given buying KP281, KP481, KP781 ?#

# %%
#cell 36
df['Product'].value_counts()
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %%
#cell 37
m2 = df[df['Product']=='KP281'].groupby(['Product','Gender']).size().reset_index()
m2
# Out:
#   Product  Gender   0
# 0   KP281  Female  40
# 1   KP281    Male  40

# %%
#cell 38
Total = m2[0].sum(axis=0)
Total
# Out:
# 80

# %% [markdown]
# Q1.What is the probability of being a male given buying KP281?
#
# SOL: P(Male/KP281) => P(Male & KP281)/KP281 => 40/80 => 0.5 ie 50.0%.
#
# Q2.What is the probability of being a female given buying KP281?
#
# SOL: P(Male/KP281) => P(Female & KP281)/KP281 => 40/80 => 0.5 ie 50.0%.

# %%
#cell 39
m21 = df[df['Product']=='KP481'].groupby(['Product','Gender']).size().reset_index()
m21
# Out:
#   Product  Gender   0
# 0   KP481  Female  29
# 1   KP481    Male  31

# %%
#cell 40
Total = m21[0].sum(axis=0)
Total
# Out:
# 60

# %% [markdown]
# Q1.What is the probability of being a male given buying KP481?
#
# SOL: P(Male/KP481) => P(Male & KP481)/KP481 => 31/60 => 0.516 ie 51.6%.
#
# Q2.What is the probability of being a female given buying KP481?
#
# SOL: P(Male/KP481) => P(Female & KP481)/KP481 => 29/60 => 0.483 ie 48.3%.

# %%
#cell 41
m22 = df[df['Product']=='KP781'].groupby(['Product','Gender']).size().reset_index()
Total = m22[0].sum(axis=0)
m22
# Out:
#   Product  Gender   0
# 0   KP781  Female   7
# 1   KP781    Male  33

# %% [markdown]
# Q1.What is the probability of being a male given buying KP781?
#
# SOL: P(Male/KP781) => P(Male & KP781)/KP781 => 33/40 => 0.825 ie 82.5%.
#
# Q2.What is the probability of being a female given buying KP781?
#
# SOL: P(Male/KP781) => P(Female & KP781)/KP781 => 7/40 => 0.175 ie 17.5%.

# %% [markdown]
# # Probaility of both female and male given buying KP281, KP481, KP781 ends..

# %%
#cell 42
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
#cell 43
m3 = df.select_dtypes(exclude=[object])

# %%
#cell 44
m3.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
#cell 45
conditions = [
    (df['Age'] <= 10),
    (df['Age'] <= 20) & (df['Age'] > 10),
    (df['Age'] <= 30) & (df['Age'] > 20),
    (df['Age'] <= 40) & (df['Age'] > 30),
    (df['Age'] <= 50) & (df['Age'] > 40),
    (df['Age'] > 50) ]

values = ['0 - 10 years','10 - 20 years','20 - 30 years','30 - 40 years','40 - 50 years','50+ years']

# %%
#cell 46
df['Age Groups'] = np.select(conditions,values)
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles     Age Groups
# 0      112  10 - 20 years
# ...

# %%
#cell 47
KP781_df = df[df['Product'] == 'KP781']
KP481_df = df[df['Product'] == 'KP481']
KP281_df = df[df['Product'] == 'KP281']

# %%
#cell 48
len(KP281_df)
# Out:
# 80

# %%
#cell 49
KP481_df.head()
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80   KP481   19    Male         14        Single      3        3   31836
# 81   KP481   20    Male         14        Single      2        3   32973
# 82   KP481   20  Female         14     Partnered      3        3   34110
# 83   KP481   20    Male         14        Single      3        3   38658
# 84   KP481   21  Female         14     Partnered      5        4   34110
#
#     Miles     Age Groups
# 80     64  10 - 20 years
# 81     53  10 - 20 years
# 82    106  10 - 20 years
# 83     95  10 - 20 years
# 84    212  20 - 30 years

# %%
#cell 50
KP481_df.head()
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80   KP481   19    Male         14        Single      3        3   31836
# 81   KP481   20    Male         14        Single      2        3   32973
# 82   KP481   20  Female         14     Partnered      3        3   34110
# 83   KP481   20    Male         14        Single      3        3   38658
# 84   KP481   21  Female         14     Partnered      5        4   34110
#
#     Miles     Age Groups
# 80     64  10 - 20 years
# 81     53  10 - 20 years
# 82    106  10 - 20 years
# 83     95  10 - 20 years
# 84    212  20 - 30 years

# %%
#cell 51
s = KP781_df.groupby(['Age Groups','Gender']).count().reset_index().rename(columns={0 : 'Qty'})

# %%
#cell 52
KP781_df.groupby('Gender')['Age Groups'].size()
# Out:
# Gender
# Female     7
# Male      33
# Name: Age Groups, dtype: int64

# %%
#cell 53
KP781_df.groupby('Age Groups')['Gender'].size()
# Out:
# Age Groups
# 20 - 30 years    30
# 30 - 40 years     6
# 40 - 50 years     4
# Name: Gender, dtype: int64

# %%
#cell 54
KP781_df.groupby(['Age Groups','Gender']).size()
# Out:
# Age Groups     Gender
# 20 - 30 years  Female     6
#                Male      24
# 30 - 40 years  Female     1
#                Male       5
# 40 - 50 years  Male       4
# dtype: int64

# %%
#cell 55
KP781_df.groupby(['Gender','Age Groups']).size()
# Out:
# Gender  Age Groups
# Female  20 - 30 years     6
#         30 - 40 years     1
# Male    20 - 30 years    24
#         30 - 40 years     5
#         40 - 50 years     4
# dtype: int64

# %% [markdown]
# # Specific Product Prob starts here.

# %% [markdown]
# # KP781_df (Prob)

# %%
#cell 56
KP781_df = KP781_df.groupby(['Age Groups','Gender']).size().reset_index().rename(columns={0 : 'Qty'})
KP781_df
# Out:
#       Age Groups  Gender  Qty
# 0  20 - 30 years  Female    6
# 1  20 - 30 years    Male   24
# 2  30 - 40 years  Female    1
# 3  30 - 40 years    Male    5
# 4  40 - 50 years    Male    4

# %%
#cell 57
l7 = KP781_df['Qty'].sum()
l7
# Out:
# 40

# %%
#cell 58
KP781_df['Prob Buying KP781'] = (KP781_df['Qty']/l7)*100
KP781_df
# Out:
#       Age Groups  Gender  Qty  Prob Buying KP781
# 0  20 - 30 years  Female    6               15.0
# 1  20 - 30 years    Male   24               60.0
# 2  30 - 40 years  Female    1                2.5
# 3  30 - 40 years    Male    5               12.5
# 4  40 - 50 years    Male    4               10.0

# %%
#cell 59
KP781_df['Prob Buying KP781'].sum()
# Out:
# 100.0

# %% [markdown]
# # KP481_df Probability.

# %%
#cell 60
KP281_df = KP281_df.groupby(['Age Groups','Gender']).size().reset_index().rename(columns={0 : 'Qty'})
KP281_df
# Out:
#       Age Groups  Gender  Qty
# 0  10 - 20 years  Female    2
# 1  10 - 20 years    Male    4
# 2  20 - 30 years  Female   26
# 3  20 - 30 years    Male   23
# 4  30 - 40 years  Female    9
# 5  30 - 40 years    Male   10
# 6  40 - 50 years  Female    3
# 7  40 - 50 years    Male    3

# %%
#cell 61
l8 = KP281_df['Qty'].sum()
l8
# Out:
# 80

# %%
#cell 62
KP281_df['Prob Buying KP281'] = (KP281_df['Qty']/l8)*100
KP281_df
# Out:
#       Age Groups  Gender  Qty  Prob Buying KP281
# 0  10 - 20 years  Female    2               2.50
# 1  10 - 20 years    Male    4               5.00
# 2  20 - 30 years  Female   26              32.50
# 3  20 - 30 years    Male   23              28.75
# 4  30 - 40 years  Female    9              11.25
# 5  30 - 40 years    Male   10              12.50
# 6  40 - 50 years  Female    3               3.75
# 7  40 - 50 years    Male    3               3.75

# %%
#cell 63
KP281_df['Prob Buying KP281'].sum()
# Out:
# 100.0

# %% [markdown]
# # KP481_df Probability.

# %%
#cell 64
KP481_df = KP481_df.groupby(['Age Groups','Gender']).size().reset_index().rename(columns={0 : 'Qty'})
KP481_df
# Out:
#       Age Groups  Gender  Qty
# 0  10 - 20 years  Female    1
# 1  10 - 20 years    Male    3
# 2  20 - 30 years  Female   16
# 3  20 - 30 years    Male   15
# 4  30 - 40 years  Female   12
# 5  30 - 40 years    Male   11
# 6  40 - 50 years    Male    2

# %%
#cell 65
l4 = KP481_df['Qty'].sum()
l4
# Out:
# 60

# %%
#cell 66
KP481_df['Prob Buying KP481'] = (round(KP481_df['Qty']/l4,3))*100
KP481_df
# Out:
#       Age Groups  Gender  Qty  Prob Buying KP481
# 0  10 - 20 years  Female    1                1.7
# 1  10 - 20 years    Male    3                5.0
# 2  20 - 30 years  Female   16               26.7
# 3  20 - 30 years    Male   15               25.0
# 4  30 - 40 years  Female   12               20.0
# 5  30 - 40 years    Male   11               18.3
# 6  40 - 50 years    Male    2                3.3

# %%
#cell 67
# plt.figure(figsize=(9,5))

# #sns.barplot(data=KP481_df,x='Age Groups',y='Prob Buying KP481',hue='Gender')
# plt.title('Age-group with Gender-wise Buying Probability')
# plt.xticks(rotation=45)
# #plt.show()

# %% [markdown]
# # Specific Product Prob ENDS....

# %%
#cell 68
KP481_df
KP281_df
KP781_df
# Out:
#       Age Groups  Gender  Qty  Prob Buying KP781
# 0  20 - 30 years  Female    6               15.0
# 1  20 - 30 years    Male   24               60.0
# 2  30 - 40 years  Female    1                2.5
# 3  30 - 40 years    Male    5               12.5
# 4  40 - 50 years    Male    4               10.0

# %%
#cell 69
T_qty = df['Product'].value_counts().reset_index().rename(columns = {0:'KP281',1:'KP481',2:'KP781'})
T_qty
# Out:
#    index  Product
# 0  KP281       80
# 1  KP481       60
# 2  KP781       40

# %%
#cell 70
product_name = df.Product.value_counts().index
product_val = df.Product.value_counts().values

# %%
product_name
product_val
# Out:
# array([80, 60, 40], dtype=int64)

# %%
# cell 71
explode = (0.1, 0, 0)  
fig1, ax1 = plt.subplots()
ax1.pie(product_val, explode=explode, labels=product_name, autopct='%1.1f%%',shadow=True, startangle=90,radius=2.1)
''' Equal aspect ratio ensures that pie is drawn as a circle'''
ax1.axis('tight')  
plt.tight_layout()
plt.show()

# %%
#cell 72
len(product_val)
# Out:
# 3

# %% [markdown]
# # Observation from Pieplot.

# %% [markdown]
# 1) Nearly 78 % of Aerofits sales comes from KP281 and KP481 and are mostly comprises of Male and Female of agegroup 20-30.
#
#
#
# 2) Out of 22 % of Aerofits product KP781 most customers are female.

# %%
#cell 73
# plt.subplot(1,3,1)
# sns.barplot(data=KP481_df,x='Age Groups',y='Prob Buying KP481',hue='Gender',palette='YlOrRd')
# plt.title('Gender-wise Buying Probability for KP481')
# plt.xticks(rotation=45)

# plt.subplot(1,3,2)
# sns.barplot(data=KP281_df,x='Age Groups',y='Prob Buying KP281',hue='Gender',palette='YlOrRd')
# plt.title('Gender-wise Buying Probability for KP281')
# plt.xticks(rotation=45)

# plt.subplot(1,3,3)
# sns.barplot(data=KP781_df,x='Age Groups',y='Prob Buying KP781',hue='Gender',palette='YlOrRd')
# plt.title('Gender-wise Buying Probability for KP781')
# plt.xticks(rotation=45)

# plt.subplots_adjust(left=1,bottom=.1,right=3,top=1, wspace=0.4, hspace=0.4)

# plt.show()

# %%
#cell 74
KP281_df['Prob Buying KP281'].sum()
KP481_df['Prob Buying KP481'].sum()
KP781_df['Prob Buying KP781'].sum()
# Out:
# 100.0

# %% [markdown]
# # Observation from Barplot

# %% [markdown]
#  1) Aerofit should mostly target age-group of 20-30 years.
#
# 2) Aerofit should mostly target Females of age-group of 20-30 years for product KP781, as most of the buyers are male.
#
# 3) Aerofit should target both male and female of age-group of 20-30 for products KP481 and KP281.

# %%
#cell 75
corr=df.corr()

# %%
#cell 76
# plt.figure(figsize=(13,6))
# sns.heatmap(corr,annot=True,cmap='Blues_r')
# plt.title('Correlation between diffrent quantitative values.')

# plt.yticks(rotation=0)

# plt.show()

# %% [markdown]
# # Observation from heatmap

# %% [markdown]
# Key Notes.
#
# 1) Usage got lowered by growing age.
#
# 2) Usage got higher by fitness.
#
# 3) Fitness got higher by miles.

# %% [markdown]
# # Fitness

# %%
#cell 77
Fitness_df = df.groupby(['Fitness','Product']).size().reset_index().rename(columns={'Fitness':'Fitness Level',0:'Quantity'})
Fitness_df
# Out:
#     Fitness Level Product  Quantity
# 0               1   KP281         1
# 1               1   KP481         1
# 2               2   KP281        14
# 3               2   KP481        12
# 4               3   KP281        54
# 5               3   KP481        39
# 6               3   KP781         4
# 7               4   KP281         9
# 8               4   KP481         8
# 9               4   KP781         7
# 10              5   KP281         2
# 11              5   KP781        29

# %%
#cell 78
# plt.figure(figsize=(13,5))
# sns.barplot(data=Fitness_df,hue='Product',y='Quantity',x='Fitness Level',palette='YlOrRd')
# plt.title('Products bought according to fitness catagory')

# plt.show()

# %%
#cell 79
df.head(1)
# Out:
#   Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  Miles  \
# 0   KP281   18   Male         14        Single      3        4   29562    112
#
#       Age Groups
# 0  10 - 20 years

# %% [markdown]
# # Conditional probability, Joint probability, Marginal probability.

# %% [markdown]
# # Conditional Probability
#
#
# Let's take another look at the joint probability of Fitness and Product.

# %%
#cell 80
Joint_vals_fitness = pd.crosstab(df['Fitness'],df['Product'],normalize=True)
Joint_vals_fitness
# Out:
# Product     KP281     KP481     KP781
# Fitness
# 1        0.005556  0.005556  0.000000
# 2        0.077778  0.066667  0.000000
# 3        0.300000  0.216667  0.022222
# 4        0.050000  0.044444  0.038889
# 5        0.011111  0.000000  0.161111

# %% [markdown]
# # Marginal Probability

# %%
#cell 81
fitness = Joint_vals_fitness.sum(axis=1)
fitness
# Out:
# Fitness
# 1    0.011111
# 2    0.144444
# 3    0.538889
# 4    0.133333
# 5    0.172222
# dtype: float64

# %% [markdown]
# When calculated from a joint Probability, the Probability of one variable is called a marginal Probability. So the above is the marginal Probability of fitness.

# %%
#cell 82
product = Joint_vals_fitness.sum(axis=0)
product
# Out:
# Product
# KP281    0.444444
# KP481    0.333333
# KP781    0.222222
# dtype: float64

# %% [markdown]
# When calculated from a joint Probability, the Probability of one variable is called a marginal Probability. So the above is the marginal Probability of product.

# %%
#cell 83
pd.crosstab(df["Fitness"], df["Product"], 
            normalize=True, margins=True)
# Out:
# Product     KP281     KP481     KP781       All
# Fitness
# 1        0.005556  0.005556  0.000000  0.011111
# 2        0.077778  0.066667  0.000000  0.144444
# 3        0.300000  0.216667  0.022222  0.538889
# 4        0.050000  0.044444  0.038889  0.133333
# 5        0.011111  0.000000  0.161111  0.172222
# All      0.444444  0.333333  0.222222  1.000000

# %% [markdown]
# The above code snippet is another way to find marginal Probability using pd.crosstab() method.

# %% [markdown]
# When calculated from a joint Probability, the Probability of one variable is called a marginal Probability. So the above is the marginal Probability of product.

# %% [markdown]
# # Conditional probability, Joint probability, Marginal probability ends.

# %%
#cell 84
cond_Prob = Joint_vals_fitness.divide(product,axis=1)
cond_Prob.plot.bar(figsize=(15,6),grid=True)
# plt.title('Every probability in this table represents a conditional probability of product given fitness level ie P( product | fitness level ).')
# Out:
# <AxesSubplot:xlabel='Fitness'>

# %% [markdown]
# # Observations from fitness barplot...

# %% [markdown]
# key Notes.
#
# 1) Probability of using KP281 is much higher by level 3 users then others. Aerofit should focus on retaining level 3 users and should focus on increasing level2 and level4 users as they aslo use KP281.
#
# 2) Probability of using KP481 is much higher by level 3 users then others. Aerofit should focus on retaining level 3 users and should focus on increasing level2 and level4 users as they aslo use KP281.
#
# 3) Probability of using KP781 is much higher by level 5 users then others. Aerofit should focus on retaining level 5 users and should focus on increasing level3 and level4 users as they aslo use KP281.

# %%
#cell 85
df['Fitness'].value_counts()
# Out:
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: Fitness, dtype: int64

# %%
#cell 86
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0   KP281   18    Male         14        Single      3        4   29562
# 1   KP281   19    Male         15        Single      2        3   31836
# 2   KP281   19  Female         14     Partnered      4        3   30699
# 3   KP281   19    Male         12        Single      3        3   32973
# 4   KP281   20    Male         13     Partnered      4        2   35247
#
#    Miles     Age Groups
# 0    112  10 - 20 years
# 1     75  10 - 20 years
# 2     66  10 - 20 years
# 3     85  10 - 20 years
# 4     47  10 - 20 years

# %% [markdown]
# what is the probability of buying products according to income?

# %%
#cell 87
df.groupby(['Income','Age Groups'])['Product'].size().reset_index().sort_values(by=['Product'],ascending=False)
# Out:
#     Income     Age Groups  Product
# 20   45480  20 - 30 years       13
# 15   40932  20 - 30 years        6
# 31   50028  20 - 30 years        5
# 22   46617  20 - 30 years        5
# 38   52302  30 - 40 years        5
# ..     ...            ...      ...
# 51   57987  20 - 30 years        1
# 52   57987  30 - 40 years        1
# 54   58516  20 - 30 years        1
# 57   60261  40 - 50 years        1
# 88  104581  40 - 50 years        1
#
# [89 rows x 3 columns]

# %%
#cell 88
x = df.groupby(['Income'])['Product'].size().reset_index().sort_values(by=['Product'],ascending=False)
#sns.boxplot(data=x,hue='Product',x='Product',y='Income')

# %% [markdown]
# # Extra...

# %%
#cell 89
z = df.groupby(['Income','Usage','Product']).size().reset_index().sort_values(ascending=False,by=[0])

# %%
#cell 90
# plt.figure(figsize=(13,6))
# plt.title('Income-wise Products Median, IQR')
zz = z[['Product','Income']]
# sns.boxplot(x='Product',y='Income',data=zz,palette='hsv')
# plt.show()

# %% [markdown]
# # Observations from boxplot

# %% [markdown]
# 1) High Income people mostly buy KP781.
#
# more to come...

# %%
#cell 91
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
#  9   Age Groups     180 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 14.2+ KB

# %%
#cell 92
# sns.pairplot(df,hue='Product',palette='YlOrRd',markers=["o", "s", "D"],height=2)
# plt.xticks(rotation=45)
# plt.show()

# %% [markdown]
# # Observations from pairplot:

# %% [markdown]
#  key note:
#
# 1) All the high income personale depends on KP781 product. There is a clear uptrend.
#
# 2) Fitness level 3 people who falls between age 20-40 mostly use KP481 and KP281.
#
# 3) By seeing at usage, users that use 3 times a week are the highest and they mostly use KP481 and KP281.
#
# 4) People who runs above 150 miles mostly uses KP781.

# %% [markdown]
# # Contingency table for every product

# %%
#cell 93
df_m.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %%
#cell 94
p = df.groupby(['Income','MaritalStatus']).size().reset_index()

#
pp = p[['Income','MaritalStatus']]
pp

#sns.boxenplot(data = p, y='Income')
# Out:
#     Income MaritalStatus
# 0    29562        Single
# 1    30699     Partnered
# 2    31836        Single
# 3    32973     Partnered
# 4    32973        Single
# ..     ...           ...
# 82   95508     Partnered
# 83   95866     Partnered
# 84   99601     Partnered
# 85  103336     Partnered
# 86  104581     Partnered
#
# [87 rows x 2 columns]

# %%
#cell 95
# plt.figure(figsize=(13,6))
# plt.title('MaritalStatus wise Income')
# pp = p[['Income','MaritalStatus']]
# sns.boxplot(x='MaritalStatus',y='Income',data=pp,palette='hsv')
# plt.show()

# %%
#cell 96
q = df.groupby(['Product','MaritalStatus']).size().reset_index()

# %%
#cell 97
df.groupby('Product')['Miles'].sum().nunique()
# Out:
# 3

# %% [markdown]
# # Pdf creation

# %%
#cell 98
df.head(5)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0   KP281   18    Male         14        Single      3        4   29562
# 1   KP281   19    Male         15        Single      2        3   31836
# 2   KP281   19  Female         14     Partnered      4        3   30699
# 3   KP281   19    Male         12        Single      3        3   32973
# 4   KP281   20    Male         13     Partnered      4        2   35247
#
#    Miles     Age Groups
# 0    112  10 - 20 years
# 1     75  10 - 20 years
# 2     66  10 - 20 years
# 3     85  10 - 20 years
# 4     47  10 - 20 years

# %% [markdown]
# # PDF for income starts here.

# %%
#cell 99
def outlier(data):

    ans = []
    data_s = sorted(data)

    q1,q3 = np.percentile(data_s,[25,75])
    iqr = q1 - q3
    upper_bound = q3 - (1.5*iqr)
    lower_bound = q1 + (1.5*iqr)

    for i in range(len(data)):
        
        if data[i] > lower_bound and data[i] < upper_bound:
            ans.append(data[i]) 
            

    return ans

# %%
#cell 100
def sort_rt(a,b):
    d = {}
    sorted_rt = []
    followup_rt1=[]
    
    for i,j in zip(a,b):
        d[i] = j
    
    for key, value in sorted(d.items()):
        #print(key,value)
        sorted_rt.append(key)
        followup_rt1.append(value)
    return (sorted_rt,followup_rt1)

# %%
def sort_rt(a,b):
    d = {}
    sorted_rt = []
    followup_rt1=[]
    
    for i,j in zip(a,b):
        d[i] = j
    
    for key, value in sorted(d.items()):
        sorted_rt.append(key)
        followup_rt1.append(value)
    return (sorted_rt,followup_rt1)

# %%
#cell 101
# income_pdf = df['Income']

# Cleaned_data_income = np.array(outlier(income_pdf))


# income_mu = np.mean(Cleaned_data_income) 

# income_sigma = np.std(Cleaned_data_income, ddof=1)

# income_main = norm.pdf(Cleaned_data_income, loc = income_mu, scale = income_sigma)

# x,y=sort_rt(Cleaned_data_income,income_main)

# plt.plot(x,y)
# plt.title('Cleaned Normal Distribution for Income')
# plt.show()

# %%
#cell 102
age_pdf = df['Age']

Cleaned_data_age = np.array(outlier(age_pdf))



age_mu = np.mean(Cleaned_data_age) 

age_sigma = np.std(Cleaned_data_age, ddof=1)

age_main = norm.pdf(Cleaned_data_age, loc = age_mu, scale = age_sigma)

age1,age2=sort_rt(Cleaned_data_age,age_main)

plt.plot(age1,age2)
plt.title('Cleaned Normal Distribution for Age')
plt.show()

# %%
def normal_distribution(data):
    data = df['Age']
    Cleaned_data = np.array(outlier(data))
    mu = np.mean(Cleaned_data) 
    sigma = np.std(Cleaned_data, ddof=1)
    data_pdf = norm.pdf(Cleaned_data, loc = mu, scale = sigma)
    a,b=sort_rt(Cleaned_data,data_pdf)
    return a,b



a = df['Age']
c,d=normal_distribution(a)
plt.plot(c,d)

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles     Age Groups
# 0      112  10 - 20 years
# ...

# %%
#cell 103
def sort_rt(a,b):
    d = {}
    sorted_rt = []
    followup_rt1=[]
    
    for i,j in zip(a,b):
        d[i] = j
    
    for key, value in sorted(d.items()):
        #print(key,value)
        sorted_rt.append(key)
        followup_rt1.append(value)
    return (sorted_rt,followup_rt1)

# %%
#cell 104
income_pdf = df['Income']

Cleaned_data_income = np.array(outlier(income_pdf))


income_mu = np.mean(Cleaned_data_income) 

income_sigma = np.std(Cleaned_data_income, ddof=1)

income_main = norm.pdf(Cleaned_data_income, loc = income_mu, scale = income_sigma)

x,y=sort_rt(Cleaned_data_income,income_main)

plt.plot(x,y)
plt.title('Cleaned Normal Distribution for Income')
plt.show()

# %%
#cell 105
age_pdf = df['Age']

Cleaned_data_age = np.array(outlier(age_pdf))



age_mu = np.mean(Cleaned_data_age) 

age_sigma = np.std(Cleaned_data_age, ddof=1)

age_main = norm.pdf(Cleaned_data_age, loc = age_mu, scale = age_sigma)

age1,age2=sort_rt(Cleaned_data_age,age_main)

plt.plot(age1,age2)
plt.title('Cleaned Normal Distribution for Age')
plt.show()

# %%
#cell 106
sns.histplot(x,kde=True)
plt.title('Cleaned Sample of Income')

plt.show()

# %%
#cell 107
sns.histplot(df.Income,kde=True)
plt.title('Non-Cleaned Sample of Income')

plt.show()

# %% [markdown]
# # PDF for income ends here.

# %% [markdown]
# # PDF of Miles Starts here

# %%
#cell 108
pdf_2 = df['Miles']
a = np.array(pdf_2)
mu = np.mean(a)
sigma = np.std(a)
pdf_2_data = stats.norm.pdf(a,loc=mu,scale=sigma)
plt.plot(a,pdf_2_data)
plt.title('Non-Cleaned Sample of Miles')
plt.show()

# %%
#cell 109
Cleaned_data_1 = np.array(outlier(pdf_2))

Cleaned_data_mu = np.mean(Cleaned_data_1) 

Cleaned_data_sigma = np.std(Cleaned_data_1, ddof=1)

Cleaned_data_pdf = norm.pdf(Cleaned_data_1, loc = Cleaned_data_mu, scale = Cleaned_data_sigma)

#plt.plot(Cleaned_data_1,Cleaned_data_pdf)

# %%
#cell 110
rt = Cleaned_data_1.reshape(167,1)
#rt = sorted(rt)
rt1 = Cleaned_data_pdf.reshape(167,1)
#rt1 = sorted(rt1)

# %%
#cell 111
wt1 = rt.reshape(167)
wt2 = rt1.reshape(167)

d = {}
for i,j in zip(wt1,wt2):
    d[i] = j

print((sorted(d.keys())))
d1 = sorted(d.items())
d1


sorted_rt = []
followup_rt1=[]
for key, value in sorted(d.items()):
    print(key,value)
    sorted_rt.append(key)
    followup_rt1.append(value)

d
sorted_rtt = np.array(sorted_rt)

followup_rtt1 =np.array(followup_rt1)
# Out:
# [21, 38, 42, 47, 53, 56, 64, 66, 74, 75, 80, 85, 94, 95, 100, 103, 106, 112, 113, 120, 127, 132, 140, 141, 150, 160, 169, 170, 180]
# 21 0.0014403660001660887
# 38 0.003386346580325491
# 42 0.004005412812849264
# 47 0.004853520997016089
# 53 0.005953926688392444
# 56 0.006524325758743213
# 64 0.008041950596268792
# 66 0.008406785512713112
# 74 0.009726413623561225
# 75 0.009870088270834958
# 80 0.01049556292227787
# 85 0.010941975806278991
# 94 0.011220162967539998
# 95 0.011207060544041907
# 100 0.011010262481278274
# 103 0.010790853481711438
# 106 0.010500738220381183
# 112 0.009733424011131591
# 113 0.009584512359208493
# 120 0.008415397339967772
# 127 0.0071077745767649594
# 132 0.00615224479145951
# 140 0.004686370258118806
# 141 0.004513515398120485
# 150 0.0031056282294544494
# 160 0.0019014442117702567
# 169 0.0011426953765958977
# 170 0.0010755707033902218
# 180 0.0005621026015709816

# %%
#cell 112
a = pd.read_csv('aerofit_treadmill.csv')

# %%
#cell 113
plt.plot(sorted_rt,followup_rt1)
plt.show()

# %%
#cell 114
plt.stem(sorted_rt,followup_rt1)
plt.show()

# %%
#cell 115
sns.histplot(sorted_rt,kde=True)
plt.title('Cleaned Sample of Miles')

plt.show()

# %%
#cell 116
sns.histplot(df.Miles,kde=True)
plt.title('Non-Cleaned Sample of Miles')

plt.show()

# %% [markdown]
# # PDF of miles ends here

# %% [markdown]
# # Conditional probability for different catagories .

# %%
#cell 117
def cond_prob(a):
    Joint_vals_fitness = pd.crosstab(df['Usage'],df['Product'],normalize=True)
    product = Joint_vals_fitness.sum(axis=0)
    cond_Prob = Joint_vals_fitness.divide(product,axis=1)
    return plt.show(cond_Prob.plot.bar(figsize=(15,6),grid=True))

cond_prob(a)

# %%
#cell 118
def cond_prob(a):
    Joint_vals_fitness = pd.crosstab(df['Education'],df['Product'],normalize=True)
    product = Joint_vals_fitness.sum(axis=0)
    cond_Prob = Joint_vals_fitness.divide(product,axis=1)
    return plt.show(cond_Prob.plot.bar(figsize=(15,6),grid=True))

cond_prob(a)

# %%
#cell 119
def cond_prob(a):
    Joint_vals_fitness = pd.crosstab(df['Age Groups'],df['Product'],normalize=True)
    product = Joint_vals_fitness.sum(axis=0)
    cond_Prob = Joint_vals_fitness.divide(product,axis=1)
    return plt.show(cond_Prob.plot.bar(figsize=(15,6),grid=True))

cond_prob(a)

# %%
#cell 120
df_m.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# # ...............................................................................END.................................................................................
